# %% [markdown]
# # Exercise 11: Entity and Relation Extraction

# %% [markdown]
# ## Task 1: Relation extraction from Wikipedia articles
#
# Use Wikipedia to extract the relation `directedBy(Movie, Person)` by applying pattern based heuristics that utilize: *Part Of Speech Tagging*, *Named Entity Recognition* and *Regular Expressions*.
#
# #### Required Library: SpaCy
# - ```conda install -y spacy```
# - ```python -m spacy download en```

# %%
pip install -U pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (58.0.4)
# Collecting setuptools
#   Downloading setuptools-60.5.0-py3-none-any.whl (958 kB)
#      |████████████████████████████████| 958 kB 19.5 MB/s eta 0:00:01
# Requirement already satisfied: wheel in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (0.37.0)
# Collecting wheel
#   Downloading wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.0
#     Uninstalling wheel-0.37.0:
#       Successfully uninstalled wheel-0.37.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 58.0.4
#     Uninstalling setuptools-58.0.4:
#       Successfully uninstalled setuptools-58.0.4
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.2 requires ruamel-yaml, which is not installed.
# Successfully installed pip-21.3.1 setuptools-60.5.0 wheel-0.37.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (3.2.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: setuptools in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (60.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: pathy>=0.3.5 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.26.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.20.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.6)
# Requirement already satisfied: jinja2 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/maxpfl/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request, json, csv, re
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
#read tsv with input movies
def read_tsv():
    movies=[]
    with open('movies.tsv','r') as file:
        tsv = csv.reader(file, delimiter='\t')
        next(tsv) #remove header
        movies = [{'movie':line[0], 'director':line[1]} for line in tsv]
    return movies

#parse wikipedia page
def parse_wikipedia(movie):
    txt = ''
    try:
        with urllib.request.urlopen('https://en.wikipedia.org/w/api.php?format=json&action=query&prop=extracts&exintro=&explaintext=&titles='+movie) as url:
            data = json.loads(url.read().decode())
            txt = next (iter (data['query']['pages'].values()))['extract']
    except:
        pass
    return txt

# %% [markdown]
# #### 1) Parse the raw text of a Wikipedia movie page and extract named (PER) entities.

# %%
def find_PER_entities(txt):
    txt = nlp(txt)
    
    persons = []
    for e in txt.ents:
        if e.label_ == 'PERSON':
            persons.append(e.text)
    return persons

# %% [markdown]
# #### 2) Given the raw text of a Wikipedia movie page and the extracted PER entities, find the director.

# %%
#simple heuristic: find the next PER entity after the word 'directed'
def find_director(txt, persons):
     # replace special symbols with empty string and split at every whitespace
    txt = re.sub('[!?,.]', '', txt).split()
    for p1 in range(0, len(txt)):
        if(txt[p1] == 'directed'):
            for p2 in range(p1, len(txt)):
                for per in persons:
                    if per.startswith(txt[p2]):
                        return per
    # otherwise empty string that is used later
    return ''

# %%
movies = read_tsv()
movies[:10]
# Out:
# [{'movie': '13_Assassins_(2010_film)', 'director': 'Takashi Miike'},
#  {'movie': '14_Blades', 'director': 'Daniel Lee'},
#  {'movie': '22_Bullets', 'director': 'Richard Berry'},
#  {'movie': 'The_A-Team_(film)', 'director': 'Joe Carnahan'},
#  {'movie': 'Alien_vs_Ninja', 'director': 'Seiji Chiba'},
#  {'movie': 'Bad_Blood_(2010_film)', 'director': 'Dennis Law'},
#  {'movie': 'Bangkok_Knockout', 'director': 'Panna Rittikrai'},
#  {'movie': 'Blades_of_Blood', 'director': 'Lee Joon-ik'},
#  {'movie': 'The_Book_of_Eli', 'director': 'Allen Hughes'},
#  {'movie': 'The_Bounty_Hunter_(2010_film)', 'director': 'Andy Tennant'}]

# %%
statements=[]
#persons = []
tp = 0
fp = 0
retrieved = 0
gt_directors = [m['director'] for m in movies if m.get('director')]
relevant = len(gt_directors)

for m in movies:
        # Wikipedia page for movie m
        txt = parse_wikipedia(m['movie'])
        # persons of movie m
        persons = find_PER_entities(txt)
        # finds director in persons by looking at first PER after "directed"
        director = find_director(txt, persons)
            
        if director != '':
            statements.append(m['movie'] + ' is directed by ' + director + '.')
            retrieved += 1
            if director == m['director']:
                tp +=1
            else:
                fp +=1

# %%
# Testing purposes to see persons for all movies
persons
# Out:
# [['Hepburn',
#   'Takashi Miike',
#   'Kōji Yakusho',
#   'Takayuki Yamada',
#   'Sōsuke Takaoka',
#   'Hiroki Matsukata',
#   'Gorō Inagaki',
#   'Matsudaira Naritsugu',
#   'Akashi',
#   'Crows Zero 2'],
#  ['Daniel Lee',
#   'Donnie Yen',
#   'Zhao Wei',
#   'Sammo Hung',
#   'Wu Chun',
#   'Kate Tsui',
#   'Qi Yuwu'],
#  ['Richard Berry', 'Jacky Imbert', "L'Immortel"],
#  ['Frank Lupo',
#   'Stephen J. Cannell',
#   'Joe Carnahan',
#   'Carnahan',
#   'Brian Bloom',
#   'Skip Woods',
#   'Liam Neeson',
#   'Bradley Cooper',
#   'Quinton Jackson',
#   'Jessica Biel',
#   'Patrick Wilson',
#   'Yul Vazquez',
#   'Tony Scott',
#   'Ridley Scott',
#   'Cooper'],
#  ['Seiji Chiba'],
#  ['Dennis Law', 'Simon Yam', 'Bernice Liu', 'Andy'],
#  [],
#  ['Gureumeul Beoseonan Dalcheoreom', 'Lee Joon-ik', "Park Heung-yong's"],
#  ['Gary Whitta',
#   'Denzel Washington',
#   'Gary Oldman',
#   'Mila Kunis',
#   'Ray Stevenson',
#   'Jennifer Beals'],
#  ['Andy Tennant', 'Jennifer Aniston', 'Gerard Butler'],
#  ['Butcher', 'Swordsman', 'Wuershan'],
#  ['Neil Marshall', 'Michael Fassbender', 'Olga Kurylenko'],
#  [],
#  ['Breck Eisner',
#   'Scott Kosar',
#   'Ray Wright',
#   'Timothy Olyphant',
#   'Radha Mitchell',
#   'Joe Anderson',
#   'Danielle Panabaker',
#   'George A. Romero',
#   'Rotten Tomatoes'],
#  ['Shawn Levy',
#   'Josh Klausner',
#   'Steve Carell',
#   'Tina Fey',
#   'Taraji P. Henson',
#   'Mark Wahlberg'],
#  ['David Callaham',
#   'Sylvester Stallone',
#   'Jason Statham',
#   'Jet Li',
#   'Dolph Lundgren',
#   'Randy Couture',
#   'Terry Crews',
#   'Steve Austin',
#   'Mickey Rourke',
#   "Dolph Lundgren's",
#   'Johnny Mnemonic'],
#  ['Faster',
#   'George Tillman Jr.',
#   'Dwayne Johnson',
#   'Billy Bob Thornton',
#   'Tom Berenger',
#   'Oliver Jackson-Cohen',
#   'Adewale Akinnuoye-Agbaje',
#   'Carla Gugino',
#   'Faster'],
#  ['Dante Lam', 'Leon Lai'],
#  ['John Travolta', 'Pierre Morel', 'Luc Besson'],
#  ['Derek Kwok',
#   'Clement Cheng',
#   'Leung Siu-lung',
#   'Chen Kuan-tai',
#   'Teddy Robin'],
#  ['Gosu Rori Shokeinin',
#   'Rina Akiyama',
#   'Ruito Aoyagi',
#   'Minami Tsukui',
#   'Misaki Momose',
#   'Yurei Yanagi',
#   'Satoshi Hakuzen',
#   'Asami Sugiura'],
#  ['Christopher Nolan',
#   'Emma Thomas',
#   'Leonardo DiCaprio',
#   'Ken Watanabe',
#   'Joseph Gordon-Levitt',
#   'Elliot Page',
#   'Tom Hardy',
#   'Cillian Murphy',
#   'Tom Berenger',
#   'Michael Caine',
#   'Prestige'],
#  ['Ip Man',
#   'Ip Man',
#   'Wing Chun',
#   'Wilson Yip',
#   'Donnie Yen',
#   'Wing Chun',
#   'Hung Ga',
#   'Hung Chun-nam',
#   'Sammo Hung',
#   'Taylor',
#   'Miller',
#   'Darren Shahlavi',
#   'Raymond Wong',
#   "Ip Man's",
#   'Bruce Lee',
#   'Lee',
#   'Lee',
#   'Yip',
#   'Edmond Wong',
#   "Sammo Hung's",
#   "Ip Man's",
#   'Ip Man'],
#  ['Iron Man',
#   'Iron Man',
#   'Jon Favreau',
#   'Justin Theroux',
#   'Robert Downey Jr.',
#   'Tony Stark',
#   'Gwyneth Paltrow',
#   'Don Cheadle',
#   'Scarlett Johansson',
#   'Sam Rockwell',
#   'Mickey Rourke',
#   'Samuel L. Jackson',
#   'Iron Man',
#   'Tony Stark',
#   'Ivan Vanko',
#   'Stark',
#   'Iron Man',
#   'Favreau',
#   'Jackson',
#   'Iron Man',
#   'Cheadle',
#   'Terrence Howard',
#   'James Rhodes',
#   'Iron Man'],
#  ['Kevin Chu', 'Xiao Shen Yang'],
#  ['Kick-Ass',
#   'Matthew Vaughn',
#   'Jane Goldman',
#   'Mark Millar',
#   'John Romita',
#   'Dave Lizewski',
#   'Aaron Johnson',
#   'Dave',
#   'Nicolas Cage',
#   "Frank D'Amico",
#   'Mark Strong',
#   'Red Mist',
#   'Christopher Mintz-Plasse',
#   'Kick-Ass',
#   'Jeff Wadlow',
#   'Johnson'],
#  ['Robert Luketic', 'Katherine Heigl', 'Ashton Kutcher', 'Kutcher'],
#  ['James Mangold',
#   'Tom Cruise',
#   'Cameron Diaz',
#   'Cruise',
#   'Diaz',
#   'June Havens',
#   'Roy Miller',
#   'Cruise',
#   'Cruise',
#   'Knight',
#   'Day',
#   'Cruise',
#   'Diaz',
#   'Bang Bang',
#   'Hrithik Roshan',
#   'Katrina Kaif'],
#  [],
#  [],
#  ['Jiang Wen',
#   'Ma Shitu',
#   'Zhang',
#   'Jiang Wen',
#   'Chow Yun',
#   'Ge You',
#   'Carina Lau',
#   'Chen Kun',
#   'Zhou Yun',
#   'Jiang Wen',
#   'Painted Skin'],
#  ['Bīng Xiǎo Jiàng',
#   'Daai6 Bing1',
#   'Zeong1',
#   'Ding Sheng',
#   'Jackie Chan',
#   'Chan',
#   'Leehom Wang',
#   'Chan',
#   'Chan'],
#  ['Peter Berg',
#   'James Vanderbilt',
#   'Andy Diggle',
#   'Sylvain White',
#   'Jeffrey Dean Morgan',
#   'Zoe Saldana',
#   'Chris Evans',
#   'Idris Elba'],
#  ['Jorma Taccone',
#   'Will Forte',
#   'Kristen Wiig',
#   'Vicki St. Elmo',
#   'Ryan Phillippe',
#   'Maya Rudolph',
#   'Casey',
#   'Val Kilmer',
#   'Dieter von Cunth'],
#  ['Robert Rodriguez',
#   'Ethan Maniquis',
#   "Quentin Tarantino's",
#   'Danny Trejo',
#   'Robert De Niro',
#   'Jessica Alba',
#   'Don Johnson',
#   'Michelle Rodriguez',
#   'Steven Seagal',
#   'Lindsay Lohan',
#   'Trejo',
#   'Seagal'],
#  ['Sentō Shōjo', 'Noboru Iguchi', 'Yoshihiro Nishimura', 'Rin', 'Kamen Rider'],
#  ['Ong-Bak',
#   'Tony Jaa',
#   'Panna Rittikrai',
#   'Ong Bak',
#   'Tien',
#   'Tony Jaa',
#   'Sarunyu Wongkrajang',
#   'Bua',
#   'Nirut Sirijanya',
#   'Bhuti Sangkha',
#   'Dan Chupong'],
#  ['Fouad Mikati', 'Disc'],
#  ['Nimród Antal',
#   'Adrien Brody',
#   'Topher Grace',
#   'Alice Braga',
#   'Walton Goggins',
#   'Laurence Fishburne',
#   'Adrien Brody',
#   'Robert Rodriguez',
#   'Alien',
#   'Aliens'],
#  ['Robert Schwentke',
#   'Jon Hoeber',
#   'Erich Hoeber',
#   'Bruce Willis',
#   'John Malkovich',
#   'Karl Urban',
#   'Mary-Louise Parker',
#   'Rebecca Pidgeon',
#   'Brian Cox',
#   'Richard Dreyfuss',
#   'Julian McMahon',
#   'Ernest Borgnine',
#   'James Remar',
#   'Frank Moses',
#   'Comedy Film'],
#  ['Daeng', 'Wisit Sasanatieng'],
#  ['Su Chao-pin', 'John Woo', 'Michelle Yeoh', 'John Woo', 'Su Chao-pin'],
#  ['Miguel Sapochnik',
#   'Jude Law',
#   'Forest Whitaker',
#   'Liev Schreiber',
#   'Alice Braga',
#   'Carice van Houten',
#   'Eric Garcia'],
#  ['Phillip Noyce',
#   'Kurt Wimmer',
#   'Angelina Jolie',
#   'Liev Schreiber',
#   'Daniel Olbrychski',
#   'Arthur Kade',
#   'Jolie',
#   'Evelyn Salt',
#   'Tom Cruise',
#   'Brian Helgeland',
#   'Jolie',
#   'Jolie',
#   'Disc'],
#  ['Scott Pilgrim',
#   'Edgar Wright',
#   'Scott Pilgrim',
#   "Bryan Lee O'Malley",
#   'Michael Cera',
#   'Scott Pilgrim',
#   'Ramona Flowers',
#   'Mary Elizabeth Winstead',
#   'Wright',
#   'Beck',
#   'Scott Pilgrim'],
#  ['Mo Ali',
#   'Paul Van Carter',
#   'Adam Deacon',
#   'Jennie Jacques',
#   'Kaya Scodelario',
#   'Kedar Williams-Stirling',
#   'Rory Beresford'],
#  ['Tom Berenger',
#   'Vinnie Jones',
#   'Tommy Flanagan',
#   'Autumn Reeser',
#   'Keegan Connor Tracy',
#   'Ernie Hudson',
#   "Joe Carnahan's",
#   'jockey'],
#  ['Brian Levant',
#   'Jonathan Bernstein',
#   'James Greer',
#   'Gregory Poirier',
#   'Robert Simonds',
#   'David Newman',
#   'Jackie Chan',
#   'Magnús Scheving',
#   'Madeline Carroll',
#   'Will Shadley',
#   'Billy Ray Cyrus',
#   'George Lopez',
#   'Chan',
#   'Chan'],
#  ['Jim Mickle',
#   'Nick Damici',
#   'Connor Paolo',
#   'Danielle Harris',
#   'Kelly McGillis'],
#  ['Xiàn Rén',
#   'Dante Lam',
#   'Nicholas Tse',
#   'Nick Cheung',
#   'Gwei Lun-mei',
#   'Don Lee',
#   'Lee',
#   'Barbarian',
#   'Lu Yi'],
#  [],
#  ['Derek Yee',
#   'Louis Koo',
#   'Daniel Wu',
#   'Yee',
#   'Wu',
#   'Leslie Cheung',
#   'Alex Fong'],
#  ['Yuen Woo-ping',
#   'Tai Chi Boxer',
#   'Vincent Zhao',
#   'Zhou Xun',
#   'Jay Chou',
#   'Michelle Yeoh',
#   'Andy',
#   'David Carradine',
#   'Guo Xiaodong',
#   'Feng Xiaogang',
#   'Cung Le',
#   'Gordon Liu',
#   'Bryan Leung',
#   'Jacky Heung',
#   'Bill Kong'],
#  ['Tony Scott', 'Denzel Washington', 'Chris Pine', 'Tony Scott'],
#  ['Sngmoo Lee',
#   'Jang Dong-gun',
#   'Kate Bosworth',
#   'Geoffrey Rush',
#   'Danny Huston',
#   'Tony Cox',
#   'Barrie Osborne',
#   'Yang',
#   'Jang Dong-gun',
#   'Ron',
#   'Geoffrey Rush',
#   'Lynne',
#   'Kate Bosworth'],
#  ['Na Hong-jin',
#   'Ha Jung-woo',
#   'Kim Yoon',
#   'Chaser',
#   'Ha Jung-woo',
#   'Kim Yoon',
#   'Ha Jung-woo',
#   'Kim Yoon'],
#  ['Zeburāman -Zebura Shiti',
#   'Show Aikawa',
#   'Riisa Naka',
#   'Masahiro Inoue',
#   'Shirokuro'],
#  ['Ruben Fleischer',
#   'Jesse Eisenberg',
#   'Danny McBride',
#   'Aziz Ansari',
#   'Nick Swardson',
#   'Brian Wells'],
#  ['Joe Cornish',
#   'John Boyega',
#   'Jodie Whittaker',
#   'Nick Frost',
#   'Boyega',
#   'Steven Price',
#   'Boyega'],
#  ['Jonathan Liebesman',
#   'Chris Bertolini',
#   'Aaron Eckhart',
#   'Michelle Rodriguez',
#   'Ramon Rodriguez',
#   'Bridget Moynahan',
#   'Michael Peña',
#   'Brian Tyler'],
#  ['Lee Joon-ik',
#   'Jung Jin-young',
#   'Lee Moon-sik',
#   'Ryu Seung-ryong',
#   'Goguryeo',
#   'Lee Joon-ik'],
#  ['Hindi-language',
#   'Puri Jagannadh',
#   'Shart',
#   'Amitabh Bachchan',
#   'Hema Malini',
#   'Prakash Raj',
#   'Sonal Chauhan',
#   'Charmy Kaur',
#   'Rajeev Verma',
#   'Raveena Tandon',
#   'Amol Rathod',
#   'S. R. Shekhar'],
#  ['Singham',
#   'Hindi-language',
#   'Rohit Shetty',
#   'Yunus Sajawal',
#   'Ajay Devgn',
#   'Bajirao Singham',
#   'Kajal Aggarwal',
#   'Prakash Raj',
#   "Salman Khan's",
#   'Singham Returns',
#   'Kareena Kapoor Khan',
#   'Simmba',
#   'Ranveer Singh',
#   'Sara Ali Khan',
#   'Karan Johar',
#   'Sooryavanshi',
#   'Akshay Kumar'],
#  ['Hindi-language',
#   'Atul Agnihotri',
#   'Alvira Khan Agnihotri',
#   'Salman Khan',
#   'Kareena Kapoor',
#   'Raj Babbar',
#   'Mahesh Manjrekar',
#   'Hazel Keech',
#   'Bollywood'],
#  ['America',
#   'America',
#   'Joe Johnston',
#   'Christopher Markus',
#   'Stephen McFeely',
#   'Chris Evans',
#   'Steve Rogers',
#   'Tommy Lee Jones',
#   'Hugo Weaving',
#   'Hayley Atwell',
#   'Sebastian Stan',
#   'Dominic Cooper',
#   'Derek Luke',
#   'Stanley Tucci',
#   'Steve Rogers',
#   'America',
#   'Jon Favreau',
#   'Louis Leterrier',
#   'Lola',
#   'America',
#   'America'],
#  [],
#  ['Robert E. Howard',
#   'Arnold Schwarzenegger',
#   'Jason Momoa',
#   'Rachel Nichols',
#   'Rose McGowan',
#   'Stephen Lang',
#   'Ron Perlman',
#   'Bob Sapp',
#   'Nu Image/Millennium Films',
#   'Brett Ratner'],
#  [],
#  ['Jung Jae-young', 'Huh Jong-ho'],
#  ['Chris Gorak',
#   'Jon Spaihts',
#   'Timur Bekmambetov',
#   'Emile Hirsch',
#   'Max Minghella',
#   'Olivia Thirlby',
#   'Rachael Taylor',
#   'Joel Kinnaman'],
#  [],
#  ['Drive Angry',
#   'Drive Angry 3D',
#   'Patrick Lussier',
#   'Todd Farmer',
#   'Nicolas Cage',
#   'William Fichtner',
#   'Billy Burke',
#   'Charlotte Ross',
#   'Katy Mixon',
#   'Tom Atkins'],
#  ['Justin Lin',
#   'Chris Morgan',
#   'Vin Diesel',
#   'Paul Walker',
#   'Jordana Brewster',
#   'Tyrese Gibson',
#   'Chris',
#   'Bridges',
#   'Matt Schulze',
#   'Sung Kang',
#   'Tego Calderon',
#   'Don Omar',
#   'Dwayne Johnson',
#   'Joaquim de Almeida',
#   'Dominic Toretto',
#   "Brian O'Conner",
#   'Luke Hobbs',
#   'Lin',
#   'Rio de Janeiro',
#   'Brian Tyler',
#   'Lin',
#   'Johnson'],
#  ['Tsui Hark',
#   'Jet Li',
#   'Zhou Xun',
#   'Chen Kun',
#   'Li Yuchun',
#   'Gwei Lun-mei',
#   'Louis Fan',
#   'Chen Kun',
#   'Gwei Lun-mei'],
#  ['George W. Trendle',
#   'Fran Striker',
#   'Michel Gondry',
#   'Evan Goldberg',
#   'Jay Chou',
#   'Christoph Waltz',
#   'Edward James Olmos',
#   'David Harbour',
#   'Tom Wilkinson',
#   'Cameron Diaz',
#   'RealD Cinema'],
#  ['Green Lantern',
#   'Ryan Reynolds',
#   'Blake Lively',
#   'Peter Sarsgaard',
#   'Mark Strong',
#   'Angela Bassett',
#   'Tim Robbins',
#   'Martin Campbell',
#   'Greg Berlanti',
#   'Michael Green',
#   'Marc Guggenheim',
#   'Michael Goldenberg',
#   'Hal Jordan',
#   'Hal',
#   'Greg Berlanti',
#   'Martin Campbell',
#   'Green Lantern'],
#  ['Joe Wright', 'Saoirse Ronan', 'Eric Bana'],
#  ['Ding Sheng', "Ding Sheng's", 'Lao San', 'Liu Ye'],
#  ['Jason Eisener',
#   'John Davies',
#   'Eisener',
#   'Rutger Hauer',
#   'Robert Rodriguez'],
#  ['D. J. Caruso',
#   'Alex Pettyfer',
#   'Timothy Olyphant',
#   'Teresa Palmer',
#   'Dianna Agron',
#   'Callan McAuliffe',
#   'Alfred Gough',
#   'Michael Bay'],
#  ['Yoshikatsu Kimura', 'Rina Takeda'],
#  ['Denjin Zabōgā', 'Noboru Iguchi', 'Denjin Zaborger'],
#  ['Kick', 'Prachya Pinkaew'],
#  ['Killer Elite',
#   'Jason Statham',
#   'Clive Owen',
#   'Robert De Niro',
#   'Ranulph Fiennes',
#   'Gary McKendry'],
#  ['Kung Fu Panda 2',
#   'Kung Fu Panda',
#   'Jennifer Yuh Nelson',
#   'Jack Black',
#   'Angelina Jolie',
#   'Dustin Hoffman',
#   'Seth Rogen',
#   'Lucy Liu',
#   'David Cross',
#   'James Hong',
#   'Jackie Chan',
#   'Gary Oldman',
#   'Michelle Yeoh',
#   'Danny McBride',
#   'Dennis Haysbert',
#   'Jean-Claude Van Damme',
#   'Victor Garber',
#   'RealD 3D',
#   'Frozen',
#   'Rango',
#   'Nelson',
#   'Kung Fu Panda'],
#  [],
#  ['Julian Gilbey',
#   'Will Gilbey',
#   'Melissa George',
#   'Ed Speleers',
#   'Karel Roden',
#   'Eamonn Walker',
#   'Sean Harris',
#   'Kate Magowan'],
#  ['Guan Yu',
#   'Romance',
#   'Alan Mak',
#   'Felix Chong',
#   'Donnie Yen',
#   'Guan Yu',
#   'Yen'],
#  ['Simon West',
#   'Jason Statham',
#   'Ben Foster',
#   'Lewis John Carlino',
#   'Richard Wenk'],
#  ['Brad Bird',
#   'Josh Appelbaum',
#   'André Nemec',
#   'Tom Cruise',
#   'Ethan Hunt',
#   'Jeremy Renner',
#   'Simon Pegg',
#   'Paula Patton',
#   'Michael Nyqvist',
#   'Anil Kapoor',
#   'Léa Seydoux',
#   'Hunt',
#   'Hunt',
#   'Hunt',
#   'Cruise',
#   'Rotten Tomatoes'],
#  ['Incredible', 'Vincent Kok', 'Louis Koo', 'Sandra Ng'],
#  ['Shang Jing'],
#  ['Nintama Rantarô',
#   'Takashi Miike',
#   'Nintama Rantarō',
#   'Seishiro Kato',
#   'Rantaro'],
#  ['Fu Huayang', 'Hans Zhang', 'Zheng Shuang', 'Xing Yu', 'Melrose Hu'],
#  [],
#  [],
#  ['Takanori Tsujimoto', 'Natsuki Kato', 'Yuma Ishigaki', 'Yasuaki Kurata'],
#  ['Nicolas Cage',
#   'Ron Perlman',
#   'Dominic Sena',
#   'Claire Foy',
#   'Bragi F. Schut',
#   'Charles Roven',
#   'Alex Gartner'],
#  ['Kim Ji-hoon'],
#  ['Shaolin', 'Benny Chan', 'Andy Lau', 'Nicholas Tse', 'Jackie Chan'],
#  ['Guy Ritchie',
#   'Joel Silver',
#   'Lionel Wigram',
#   'Susan Downey',
#   'Dan Lin',
#   'John Watson',
#   'Arthur Conan Doyle',
#   'Michele Mulroney',
#   'Kieran Mulroney',
#   'Robert Downey Jr.',
#   'Jude Law',
#   'Stephen Fry',
#   'Mycroft Holmes',
#   'Jared Harris',
#   'Rachel McAdams',
#   'Irene Adler',
#   "Conan Doyle's",
#   'Holmes',
#   'Watson',
#   'Downey',
#   'Law'],
#  ['Nuit Blanche', 'Frédéric Jardin'],
#  ['Duncan Jones',
#   'Ben Ripley',
#   'Jake Gyllenhaal',
#   'Colter Stevens',
#   'Michelle Monaghan',
#   'Jeffrey Wright'],
#  ['Xu Haofeng'],
#  ['Zack Snyder',
#   'Steve Shibuya',
#   'Emily Browning',
#   'Abbie Cornish',
#   'Jena Malone',
#   'Vanessa Hudgens',
#   'Jamie Chung',
#   'Carla Gugino',
#   'Oscar Isaac'],
#  ['Kenneth Branagh',
#   'Ashley Edward Miller',
#   'Zack Stentz',
#   'Don Payne',
#   'Chris Hemsworth',
#   'Natalie Portman',
#   'Tom Hiddleston',
#   'Stellan Skarsgård',
#   'Colm Feore',
#   'Ray Stevenson',
#   'Idris Elba',
#   'Rene Russo',
#   'Anthony Hopkins',
#   'Loki',
#   'Sam Raimi',
#   'Mark Protosevich',
#   'Matthew Vaughn'],
#  ['Moon',
#   'Michael Bay',
#   'Shia LaBeouf',
#   'Josh Duhamel',
#   'John Turturro',
#   'Tyrese Gibson',
#   'Rosie Huntington-Whiteley',
#   'Patrick Dempsey',
#   'Kevin Dunn',
#   'Julie White',
#   'John Malkovich',
#   'Frances McDormand',
#   'Moon',
#   'Ehren Kruger',
#   'Moon',
#   'Moon',
#   'IMAX 3D',
#   'Dolby Surround'],
#  ['Chen Jin', 'Pang Juan', 'Sun Bin'],
#  ['Daniel Lee',
#   'Leon Lai',
#   'Feng Shaofeng',
#   'Liu Yifei',
#   'Zhang Hanyu',
#   'Anthony Wong',
#   'Jordan Chan',
#   'Andy',
#   'Xiu Qing',
#   'Jia Qing',
#   'Qin'],
#  [],
#  ['Matthew Vaughn',
#   'Bryan Singer',
#   'James McAvoy',
#   'Michael Fassbender',
#   'Rose Byrne',
#   'Jennifer Lawrence',
#   'January Jones',
#   'Oliver Platt',
#   'Kevin Bacon',
#   'Charles Xavier',
#   'Erik Lehnsherr / Magneto',
#   'Sebastian Shaw',
#   'Lauren Shuler',
#   'Simon Kinberg',
#   'Jane Goldman',
#   'Magneto',
#   'Magneto',
#   'Sheldon Turner',
#   'James Bond',
#   'Dark Phoenix'],
#  ['Gokudō Heiki', 'Ken Ishikawa', 'Shozo Iwaki'],
#  ['Phil',
#   'Christopher Miller',
#   'Jonah Hill',
#   'Michael Bacall',
#   'Hill',
#   'Channing Tatum',
#   'Stephen J. Cannell',
#   'Patrick Hasburgh',
#   'Schmidt',
#   'Jenko'],
#  [],
#  ['Hindi-language',
#   'Hiroo Yash Johar',
#   'Karan Johar',
#   'Karan Malhotra',
#   'Mukul S. Anand',
#   'Santosh Saroj',
#   'Piyush Mishra',
#   'Johar',
#   'Yash Johar',
#   'Amitabh Bhattacharya',
#   'Harivansh Rai Bachchan',
#   'Hrithik Roshan',
#   'Vijay Deenanath Chauhan',
#   'Sanjay Dutt',
#   'Kancha Cheena',
#   'Amitabh Bachchan',
#   'Danny Denzongpa',
#   'Rishi Kapoor',
#   'Rauf Lala',
#   'Kaali Gawde',
#   'Zarina Wahab',
#   'Suhasini Chauhan',
#   'Katrina Kaif',
#   'Vijay',
#   'Rauf',
#   'Kaali Gawde',
#   'Zee Cine Awards'],
#  [],
#  ['Joss Whedon',
#   'Robert Downey Jr.',
#   'Chris Evans',
#   'Mark Ruffalo',
#   'Chris Hemsworth',
#   'Scarlett Johansson',
#   'Jeremy Renner',
#   'Tom Hiddleston',
#   'Clark Gregg',
#   'Cobie Smulders',
#   'Stellan Skarsgård',
#   'Samuel L. Jackson',
#   'Nick Fury',
#   'Tony Stark',
#   'Steve Rogers',
#   'Bruce Banner',
#   'Thor',
#   'Loki',
#   'Tony Stark',
#   'Steve Rogers',
#   'Bruce Banner',
#   'Natasha Romanoff',
#   'Zak Penn'],
#  ['John Kim',
#   'Russell Mulcahy',
#   'Sharni Vinson',
#   'Phoebe Tonkin',
#   'Xavier Samuel',
#   'Julian McMahon',
#   'Alex Russell',
#   'Lincoln Lewis',
#   'Dan Wyllie'],
#  ['Peter Berg',
#   'Alexander Skarsgård',
#   'Taylor Kitsch',
#   'Brooklyn Decker',
#   'Tadanobu Asano',
#   'Liam Neeson'],
#  ['Tsai Yueh-hsun', 'Mark Chao', 'Huang Bo'],
#  ['The Bourne Legacy',
#   'Tony Gilroy',
#   'Robert Ludlum',
#   'Eric Van Lustbader',
#   'The Bourne Supremacy',
#   'The Bourne Ultimatum',
#   'Lustbader',
#   'Jason Bourne',
#   'Aaron Cross',
#   'Jeremy Renner',
#   'Rachel Weisz',
#   'Edward Norton',
#   'Jason Bourne',
#   'Matt Damon',
#   'Paul Greengrass',
#   'Bourne',
#   'Tony Gilroy',
#   'The Bourne Ultimatum',
#   'Aaron Cross',
#   "Jason Bourne's",
#   'Jason Bourne'],
#  ['Baltasar Kormákur',
#   'Mark Wahlberg',
#   'Kate Beckinsale',
#   'Ben Foster',
#   'Caleb Landry Jones',
#   'Giovanni Ribisi',
#   'Diego Luna',
#   'J. K. Simmons'],
#  ['Chinese Zodiac', 'Jackie Chan', 'Chan'],
#  ['Hindi-language',
#   'Malaika Arora',
#   'Arbaaz Khan',
#   'Dilip Shukla',
#   'Salman Khan',
#   'Sonakshi Sinha',
#   'Arbaaz Khan',
#   'Mahie Gill',
#   'Vinod Khanna',
#   'Prakash Raj',
#   'Nikitin Dheer',
#   'Gireesh Sahdev',
#   'Pankaj Tripathi',
#   'Manoj Joshi',
#   'Tinnu Anand',
#   'Abhinav Kashyap',
#   'Arbaaz Khan',
#   'Dabangg',
#   'Ek Tha Tiger',
#   'Salman Khan',
#   'Bollywood',
#   'Ek Tha Tiger'],
#  ['Christopher Nolan',
#   'Jonathan Nolan',
#   'David S. Goyer',
#   'Batman',
#   'Christian Bale',
#   'Bruce Wayne / Batman',
#   'Michael Caine',
#   'Gary Oldman',
#   'Anne Hathaway',
#   'Tom Hardy',
#   'Joseph Gordon-Levitt',
#   'Bane',
#   'Bruce Wayne',
#   'Christopher Nolan',
#   'Bane',
#   'Batcave'],
#  ['Simon West',
#   'Richard Wenk',
#   'Sylvester Stallone',
#   'Ken Kaufman',
#   'David Agosto',
#   'Brian Tyler',
#   'Expendables',
#   'Sylvester Stallone',
#   'Jet Li',
#   'Dolph Lundgren',
#   'Chuck Norris',
#   'Terry Crews',
#   'Randy Couture',
#   'Liam Hemsworth',
#   'Bruce Willis',
#   'Arnold Schwarzenegger',
#   'Jean Vilain'],
#  ['David Barrett',
#   'Josh Duhamel',
#   'Bruce Willis',
#   "Vincent D'Onofrio",
#   'Rosario Dawson',
#   'Disc'],
#  ['Gordon Chan', 'Janet Chun', 'Si Da Ming Bu', 'Cold Blood', 'Master Zhuge'],
#  ['Ghost Rider',
#   'Nicolas Cage',
#   'Johnny Blaze / Ghost Rider',
#   'Ciarán Hinds',
#   'Violante Placido',
#   'Johnny Whitworth',
#   'Christopher Lambert',
#   'Idris Elba',
#   'Mark Neveldine',
#   'Brian Taylor',
#   'Scott M. Gimple',
#   'Seth Hoffman',
#   'David S. Goyer',
#   'Nicolas Cage',
#   'Robbie Reyes'],
#  ['Andrew Lau',
#   'Huang Xiaoming',
#   'Ethan Juan',
#   'Shawn Yue',
#   'Li Yuchun',
#   'Jing Boran'],
#  ['Roses', "Huángjīn Dà Jié'àn", 'Ning Hao'],
#  [],
#  ['Jack Reacher',
#   'Christopher McQuarrie',
#   'Tom Cruise',
#   'David Oyelowo',
#   'Richard Jenkins',
#   'Jai Courtney',
#   'Werner Herzog',
#   'Robert Duvall',
#   'Joe Kraemer',
#   'Jack Reacher'],
#  ['John Carter',
#   'Andrew Stanton',
#   'Mark Andrews',
#   'Michael Chabon',
#   'Edgar Rice Burroughs',
#   'Jim Morris',
#   'Colin Wilson',
#   'Lindsey Collins',
#   'John Carter',
#   'Taylor Kitsch',
#   'Lynn Collins',
#   'Mark Strong',
#   'James Purefoy',
#   'John Carter',
#   'Stanton',
#   'Pixar',
#   'Finding Nemo',
#   'Michael Giacchino',
#   'Pixar',
#   'Steve Jobs',
#   'John Carter',
#   'RealD 3D',
#   'John Carter',
#   'Giacchino',
#   'Stanton'],
#  ['Russell Crowe',
#   'Cung Le',
#   'Lucy Liu',
#   'Byron Mann',
#   'Rick Yune',
#   'Dave Bautista',
#   'Jamie Chung',
#   'Roth',
#   'Roth',
#   'Howard Drossin',
#   'Mann'],
#  ['Naked Soldier', 'Marco Mak', 'Jennifer Tse', 'Naked Weapon'],
#  ['David Koepp',
#   'John Kamps',
#   'Joseph Gordon-Levitt',
#   'Michael Shannon',
#   'Dania Ramirez',
#   'Jamie Chung'],
#  [],
#  ['Daniel Espinosa', 'Matt Weston', 'Ryan Reynolds', 'Frost'],
#  ['James Bond',
#   'Daniel Craig',
#   'James Bond',
#   'Javier Bardem',
#   'Raoul Silva',
#   'Judi Dench',
#   'Sam Mendes',
#   'Neal Purvis',
#   'Robert Wade',
#   'John Logan',
#   'Adele',
#   'MI6',
#   'Raoul Silva',
#   'Ben Whishaw',
#   'Moneypenny',
#   'Naomie Harris',
#   'Peter Morgan',
#   'Logan',
#   'Purvis',
#   'James Bond',
#   'James Bond',
#   'Spectre',
#   'Craig',
#   'Mendes'],
#  ['Tai Chi 0',
#   'Tai Chi Zero',
#   'Stephen Fung',
#   'Chen',
#   "chi ch'uan",
#   'Chen',
#   'Yang Luchan',
#   'Chen Changxing',
#   "Stephen Fung's",
#   "Daniel Wu's",
#   'Tai Chi Hero',
#   'Tai Chi Summit'],
#  ['Olivier Megaton',
#   'Liam Neeson',
#   'Famke Janssen',
#   'Rade Šerbedžija',
#   'Jon Gries',
#   'Luke Grimes',
#   'Bryan Mills',
#   'Taken',
#   'Taken 3'],
#  ['Måns Mårlind',
#   'Björn Stein',
#   'Kate Beckinsale',
#   'Theo James',
#   'Michael Ealy'],
#  ['John Hyams',
#   'Scott Adkins',
#   'Jean-Claude Van Damme',
#   'Dolph Lundgren',
#   'Andrei Arlovski',
#   'John',
#   'Luc Deveraux',
#   'Michael Haneke',
#   'David Lynch'],
#  ['Dante Lam',
#   'Jay Chou',
#   'Nicholas Tse',
#   'Lin Peng',
#   'Michelle Bai',
#   'Andy',
#   'Carl Ng',
#   'Liu Kai-chi',
#   'Elaine Jin',
#   'Chin Kar-lok'],
#  ['Wu Dang',
#   'Patrick Leung',
#   'Vincent Zhao',
#   'Yang Mi',
#   'Louis Fan',
#   'Xu Jiao'],
#  [],
#  ['Baltasar Kormákur',
#   'Denzel Washington',
#   'Mark Wahlberg',
#   'Steven Grant',
#   'Mateus Santolouco'],
#  ['Angel Warriors', 'Fu Huayang', 'Collin Chou', 'Yu Nan', 'Xing Yu', 'Andy'],
#  ['Berlin',
#   'Ryoo Seung-wan',
#   'Ha Jung-woo',
#   'Jun Ji-hyun',
#   'Ryoo Seung-bum',
#   'Han Suk-kyu'],
#  ['Walter Hill',
#   'Alessandro Camon',
#   'Colin Wilson',
#   'Sylvester Stallone',
#   'Sung Kang',
#   'Sarah Shahi',
#   'Adewale Akinnuoye-Agbaje',
#   'Christian Slater',
#   'Jason Momoa',
#   'Alexandra Milchan',
#   'Alfred Gough',
#   'Kevin King-Templeton',
#   'Kang'],
#  ['Neill Blomkamp', 'Matt Damon', 'Jodie Foster', 'Alice Braga', 'Blomkamp'],
#  ["Orson Scott Card's",
#   'Gavin Hood',
#   'Butterfield',
#   'Andrew "Ender" Wiggin',
#   'Harrison Ford',
#   'Hailee Steinfeld',
#   'Viola Davis',
#   'Abigail Breslin',
#   'Ben Kingsley'],
#  ['Sylvester Stallone',
#   'Arnold Schwarzenegger',
#   'Jim Caviezel',
#   'Vinnie Jones',
#   "Vincent D'Onofrio",
#   'Amy Ryan',
#   'Mikael Håfström',
#   'Miles Chapman',
#   'Jason Keller',
#   "Arnell Jesko'",
#   'Schwarzenegger',
#   'Ray Breslin',
#   'Emil Rottmayer'],
#  ['Justin Lin',
#   'Chris Morgan',
#   'Vin Diesel',
#   'Paul Walker',
#   'Dwayne Johnson',
#   'Michelle Rodriguez',
#   'Jordana Brewster',
#   'Tyrese Gibson',
#   'Chris',
#   'Bridges',
#   'Sung Kang',
#   'Luke Evans',
#   'Gina Carano',
#   'John Ortiz',
#   'Dominic Toretto',
#   "Brian O'Conner",
#   'Letty Ortiz',
#   'Lin',
#   'Glasgow'],
#  ['Gordon Chan', 'Janet Chun'],
#  ['Gangster Squad',
#   'Ruben Fleischer',
#   'Will Beall',
#   'Josh Brolin',
#   'Ryan Gosling',
#   'Nick Nolte',
#   'Emma Stone',
#   'Anthony Mackie',
#   'Giovanni Ribisi',
#   'Robert Patrick',
#   'Michael Peña',
#   'Sean Penn',
#   'Mickey Cohen'],
#  [],
#  ['Joe',
#   'Jon M. Chu',
#   'Rhett Reese',
#   'Paul Wernick',
#   'Ray Park',
#   'Jonathan Pryce',
#   'Arnold Vosloo',
#   'Channing Tatum',
#   'Luke Bracey',
#   'Robert Baker',
#   'Joseph Gordon-Levitt',
#   'Dwayne Johnson',
#   'Bruce Willis',
#   'D. J. Cotrona',
#   'Adrianne Palicki',
#   'Ray Stevenson',
#   'Elodie Yung',
#   'Cobra',
#   'Joseph Colton'],
#  ['John Moore',
#   'Skip Woods',
#   'Bruce Willis',
#   'John McClane',
#   'Jack',
#   'Willis',
#   'Jai Courtney',
#   'Cole Hauser',
#   'Sebastian Koch',
#   'Willis',
#   'John Moore'],
#  ['Paul Feig',
#   'Katie Dippold',
#   'Sandra Bullock',
#   'Melissa McCarthy',
#   'Demián Bichir',
#   'Marlon Wayans',
#   'Michael Rapaport',
#   'Jane Curtin',
#   'Sarah Ashburn',
#   'Shannon Mullins',
#   'McCarthy'],
#  [],
#  ['Steven Knight', 'Jason Statham'],
#  ['Iron Man',
#   'Iron Man',
#   'Iron Man',
#   'Drew Pearce',
#   'Robert Downey Jr.',
#   'Tony Stark',
#   'Gwyneth Paltrow',
#   'Don Cheadle',
#   'Guy Pearce',
#   'Rebecca Hall',
#   'Stéphanie Szostak',
#   'James Badge Dale',
#   'Jon Favreau',
#   'Ben Kingsley',
#   'Tony Stark',
#   'Favreau',
#   "Warren Ellis's",
#   'Hall'],
#  ['Kick-Ass 2',
#   'Jeff Wadlow',
#   'Mark Millar',
#   'John Romita',
#   'Jr',
#   'Aaron Taylor-Johnson',
#   'Christopher Mintz-Plasse',
#   'Dave Lizewski',
#   "Chris D'Amico",
#   'Mindy Macready',
#   'Clark Duke',
#   'Yancy Butler',
#   'Garrett M. Brown',
#   'Lyndsy Fonseca',
#   'Sophie Wu',
#   'Jim Carrey',
#   'Daniel Kaluuya',
#   'Kick-Ass 2'],
#  ['Kim Jee-woon',
#   'Arnold Schwarzenegger',
#   'Johnny Knoxville',
#   'Forest Whitaker',
#   'Jaimie Alexander',
#   'Rodrigo Santoro',
#   'Andrew Knauer',
#   "Arnold Schwarzenegger's"],
#  ['Gore Verbinski',
#   'Justin Haythe',
#   'Ted Elliott',
#   'Terry Rossio',
#   'Johnny Depp',
#   'Armie Hammer',
#   'John Reid',
#   'Lone Ranger',
#   'William Fichtner',
#   'Barry Pepper',
#   'Ruth Wilson',
#   'James Badge Dale',
#   'Tom Wilkinson',
#   'Helena Bonham Carter',
#   'Curtis Cregan',
#   "William A. Fraker's",
#   'Jerry Bruckheimer Films',
#   'Best Makeup'],
#  ['Robert Rodriguez',
#   'Danny Trejo',
#   'Michelle Rodriguez',
#   'Tom Savini',
#   'Felix Sabates',
#   'Jessica Alba',
#   'Mel Gibson',
#   'Demián Bichir',
#   'Sofía Vergara',
#   'Lady Gaga',
#   'Antonio Banderas',
#   'Cuba Gooding Jr.',
#   'Vanessa Hudgens',
#   'William Sadler',
#   'Charlie Sheen',
#   'Carlos Estévez',
#   'Trejo',
#   'Gibson'],
#  ['Superman',
#   'Superman',
#   'Zack Snyder',
#   'David S. Goyer',
#   'Christopher Nolan',
#   'Henry Cavill',
#   'Amy Adams',
#   'Michael Shannon',
#   'Kevin Costner',
#   'Diane Lane',
#   'Laurence Fishburne',
#   'Antje Traue',
#   'Ayelet Zurer',
#   'Christopher Meloni',
#   'Russell Crowe',
#   'Clark Kent',
#   'Superman',
#   'Zod',
#   "Jerry Siegel's",
#   'Superman',
#   'Siegel',
#   'Superman',
#   'Shuster',
#   'Siegel',
#   'Christopher Nolan',
#   "Hans Zimmer's",
#   'Superman'],
#  ['Joseph Kosinski',
#   'Peter Chernin',
#   'Karl Gajdusek',
#   'Michael deBruyn',
#   'Tom Cruise',
#   'Olga Kurylenko',
#   'Andrea Riseborough',
#   'Nikolaj Coster-Waldau',
#   'Kosinski',
#   'Jack Harper'],
#  ['Antoine Fuqua',
#   'Katrin Benedikt',
#   'Gerard Butler',
#   'Aaron Eckhart',
#   'Angela Bassett',
#   'Robert Forster',
#   'Ashley Judd',
#   'Melissa Leo',
#   'Dylan McDermott',
#   'Radha Mitchell',
#   'Rick Yune',
#   'Mike Banning',
#   'Benjamin Asher',
#   'Angel Has Fallen'],
#  ['Lửa Phật', 'Dustin Nguyen', 'Roger Yuan'],
#  ['Michael Bay',
#   'Mark Wahlberg',
#   'Dwayne Johnson',
#   'Anthony Mackie',
#   'Christopher Markus',
#   "Stephen McFeely's",
#   'Pete Collins',
#   'Sun Gym',
#   'Marc Schiller',
#   'Kershaw'],
#  [],
#  ['Reonningmaen', 'Shin Ha-kyun'],
#  ['J. J. Abrams',
#   'Roberto Orci',
#   'Alex Kurtzman',
#   'Damon Lindelof',
#   'Chris Pine',
#   'James T. Kirk',
#   'Zachary Quinto',
#   'Simon Pegg',
#   'Karl Urban',
#   'Zoe Saldana',
#   'John Cho',
#   'Anton Yelchin',
#   'Bruce Greenwood',
#   'Leonard Nimoy',
#   'Benedict Cumberbatch',
#   'Alice Eve',
#   'Peter Weller',
#   'Klingon',
#   'John Harrison',
#   'Orci'],
#  ['Gong Yoo', 'Won Shin-yun'],
#  ['Jay Sun', 'Andy Lau', 'Zhang Jingchu', 'Lin Chi-ling'],
#  ['Thor',
#   'Alan Taylor',
#   'Christopher Yost',
#   'Christopher Markus',
#   'Stephen McFeely',
#   'Chris Hemsworth',
#   'Natalie Portman',
#   'Tom Hiddleston',
#   'Anthony Hopkins',
#   'Stellan Skarsgård',
#   'Idris Elba',
#   'Christopher Eccleston',
#   'Adewale Akinnuoye-Agbaje',
#   'Ray Stevenson',
#   'Zachary Levi',
#   'Tadanobu Asano',
#   'Jaimie Alexander',
#   'Rene Russo',
#   'Loki',
#   'Kevin Feige',
#   'Kenneth Branagh',
#   'Brian Kirk',
#   'Patty Jenkins',
#   'Taylor',
#   'Surrey',
#   'Taylor',
#   'Carter Burwell',
#   'Brian Tyler',
#   'Hiddleston',
#   'Taylor',
#   'Taika Waititi'],
#  ['Tom Yum Goong',
#   'Prachya Pinkaew',
#   'Tom-Yum-Goong',
#   'Tony Jaa',
#   'Petchtai Wongkamlao',
#   'Kham',
#   'Mark'],
#  ['Eran Creevy', 'James McAvoy', 'Mark Strong', 'Andrea Riseborough'],
#  ['James Vanderbilt',
#   'John Cale',
#   'James Sawyer',
#   'Channing Tatum',
#   'Jamie Foxx',
#   'Maggie Gyllenhaal',
#   'Joey King',
#   'Jason Clarke',
#   'Richard Jenkins',
#   'Michael Murphy',
#   'James Woods'],
#  ['James Mangold',
#   'Scott Frank',
#   'Mark Bomback',
#   'Chris Claremont',
#   'Frank Miller',
#   'Hugh Jackman',
#   'Rila Fukushima',
#   'Tao Okamoto',
#   'Famke Janssen',
#   'Will Yun Lee',
#   'Logan',
#   "Jean Grey's",
#   'Christopher McQuarrie',
#   'Darren Aronofsky',
#   'Bomback',
#   'Logan'],
#  ['Marc Forster',
#   'Matthew Michael Carnahan',
#   'Drew Goddard',
#   'Damon Lindelof',
#   'Carnahan',
#   'J. Michael Straczynski',
#   'Max Brooks',
#   'Brad Pitt',
#   'Gerry Lane',
#   'Mireille Enos',
#   'James Badge Dale',
#   'Matthew Fox',
#   'Ludi Boeken',
#   'Fana Mokoena',
#   'David Morse',
#   'Peter Capaldi',
#   'Pierfrancesco Favino',
#   'Ruth Negga',
#   'Straczynski',
#   'Forster',
#   'Carnahan',
#   'Glasgow',
#   'Damon Lindelof',
#   'Drew Goddard',
#   "Brad Pitt's"],
#  ['Phil',
#   'Christopher Miller',
#   'Jonah Hill',
#   'Michael Bacall',
#   'Oren Uziel',
#   'Rodney Rothman',
#   'Hill',
#   'Channing Tatum',
#   'Peter Stormare',
#   'Jillian Bell',
#   'Amber Stevens',
#   'Wyatt Russell',
#   'Schmidt',
#   'Hill',
#   'Miller'],
#  ['Spider-Man',
#   'Marc Webb',
#   'Avi Arad',
#   'Matt Tolmach',
#   'Spider',
#   'James Vanderbilt',
#   'Alex Kurtzman',
#   'Roberto Orci',
#   'Andrew Garfield',
#   'Peter Parker / Spider-Man',
#   'Emma Stone',
#   'Jamie Foxx',
#   'Colm Feore',
#   'Paul Giamatti',
#   'Sally Field',
#   'Peter Parker',
#   'Gwen Stacy',
#   'Harry Osborn',
#   'Chris Cooper',
#   'Garfield',
#   "Hans Zimmer's",
#   'Foxx',
#   'Max Dillon',
#   'Andrew Garfield',
#   'Tom Holland',
#   'Garfield',
#   'Foxx',
#   'Spider'],
#  ['Tsai Yueh-Hsun', 'Mark Chao', 'Lin Gengxin', 'Huang Bo'],
#  ['Brick Mansions',
#   'Paul Walker',
#   'David Belle',
#   'Goûchy Boy',
#   'Catalina Denis',
#   'Camille Delamarre',
#   'Luc Besson',
#   'Robert Mark Kamen',
#   'Bibi Naceri',
#   'Brick Mansions'],
#  ['Lu Yang',
#   'Shen Lian',
#   'Wei Zhongxian',
#   'Chang Chen',
#   'Cecilia Liu',
#   'Wang Qianyuan'],
#  ['America',
#   'America',
#   'Anthony',
#   'Joe Russo',
#   'Christopher Markus',
#   'Stephen McFeely',
#   'Chris Evans',
#   'Steve Rogers',
#   'Scarlett Johansson',
#   'Sebastian Stan',
#   'Anthony Mackie',
#   'Cobie Smulders',
#   'Frank Grillo',
#   'Hayley Atwell',
#   'Robert Redford',
#   'Samuel L. Jackson',
#   'America',
#   'Mackie',
#   'Stan',
#   'Ed Brubaker',
#   'Russos'],
#  ['Toa Fraser'],
#  [],
#  ['Joe Lynch',
#   'Yale Hannon',
#   'Lynch',
#   'Salma Hayek',
#   'Akie Kotabe',
#   'Jennifer Blanc',
#   'Togo Igawa',
#   'Gabriella Wright',
#   'Caroline Chikezie',
#   'Laura Cepeda',
#   'Hiroyuki Watanabe',
#   'Dimension Films'],
#  ['Patrick Hughes',
#   'Katrin Benedikt',
#   'Sylvester Stallone',
#   'Sylvester Stallone',
#   'Antonio Banderas',
#   'Wesley Snipes',
#   'Dolph Lundgren',
#   'Kelsey Grammer',
#   'Randy Couture',
#   'Terry Crews',
#   'Kellan Lutz',
#   'Ronda Rousey',
#   'Glen Powell',
#   'Victor Ortiz',
#   'Mel Gibson',
#   'Harrison Ford',
#   'Arnold Schwarzenegger',
#   'Conrad Stonebanks',
#   'Expendables'],
#  ['James Gunn',
#   'Nicole Perlman',
#   'Chris Pratt',
#   'Zoe Saldaña',
#   'Dave Bautista',
#   'Vin Diesel',
#   'Bradley Cooper',
#   'Lee Pace',
#   'Michael Rooker',
#   'Karen Gillan',
#   'Djimon Hounsou',
#   'John C. Reilly',
#   'Glenn Close',
#   'Peter Quill',
#   'Perlman',
#   'Kevin Feige',
#   'Gunn',
#   'Peter Quill / Star',
#   'Tyler Bates',
#   'Gunn',
#   'Best Makeup'],
#  ['Nyotaiju Gan Ūman', 'Asami Sugiura'],
#  ['Kick Angels', 'Kazuhiro Yokoyama'],
#  ['Jack Ryan',
#   'Jack Ryan',
#   'Tom Clancy',
#   'Chris Pine',
#   'Ryan',
#   'Alec Baldwin',
#   'Harrison Ford',
#   'Ben Affleck',
#   'Kenneth Branagh',
#   'Kevin Costner',
#   'Keira Knightley',
#   'Adam Cozand',
#   'David Koepp',
#   'Mace Neufeld',
#   'Lorenzo di Bonaventura',
#   'David Barron',
#   'Mark Vahradian',
#   'David Ellison',
#   'Dana Goldberg',
#   'Paul Schwake',
#   'Tommy Harper',
#   'Patrick Doyle'],
#  ['John Wick',
#   'Chad Stahelski',
#   'Derek Kolstad',
#   'Keanu Reeves',
#   'Michael Nyqvist',
#   'Alfie Allen',
#   'Adrianne Palicki',
#   'Bridget Moynahan',
#   'Dean Winters',
#   'Ian McShane',
#   'John Leguizamo',
#   'John Wick',
#   'John Wick',
#   'Chad Stahelski',
#   'David Leitch',
#   'Stahelski',
#   'Basil Iwanyk',
#   'Michael Witherill',
#   'Stahelski',
#   'Stahelski',
#   "John Woo's",
#   'Killer',
#   "Jean-Pierre Melville's",
#   'Le Samouraï',
#   "John Boorman's",
#   'John Wick'],
#  ['Renny Harlin',
#   'Daniel Giat',
#   'Sean Hood',
#   'Kellan Lutz',
#   'Gaia Weiss',
#   'Scott Adkins',
#   'Roxanne McKee',
#   'Liam Garrigan',
#   'Hercules film',
#   'Hercules',
#   'Hercules'],
#  ['Kung Fu Jungle',
#   'Kung Fu Killer',
#   'Teddy Chan',
#   'Donnie Yen',
#   'Wang Baoqiang',
#   'Charlie Yeung  and',
#   'Michelle Bai',
#   'Kung Fu Killer',
#   'Kung Fu Jungle',
#   'Donnie Yen'],
#  ['Lucy',
#   'Luc Besson',
#   'Virginie Besson-Silla',
#   'Scarlett Johansson',
#   'Amr Waked',
#   'Johansson'],
#  ['Prison Raid',
#   'Brigitte Nielsen',
#   'Vivica A. Fox',
#   'Zoë Bell',
#   'Cynthia Rothrock',
#   'Christopher Ray',
#   'Fred Olen Ray'],
#  [],
#  ['Comedy',
#   'Tim Story',
#   'Kevin Hart',
#   'John Leguizamo',
#   'Bryan Callen',
#   'Tika Sumpter',
#   'Bruce McGill',
#   'Laurence Fishburne',
#   'Greg Coolidge',
#   'Phil Hay',
#   'Matt Manfredi',
#   'Ben Barber',
#   'James Payton',
#   'James',
#   'Ben',
#   'Rainforest Films'],
#  ['José Padilha',
#   'Joshua Zetumer',
#   'Joel Kinnaman',
#   'Gary Oldman',
#   'Michael Keaton',
#   'Samuel L. Jackson',
#   'Abbie Cornish',
#   'Jackie Earle Haley',
#   'Darren Aronofsky',
#   'David Self',
#   'Padilha',
#   'Hamilton'],
#  ['Dolph Lundgren',
#   'Tony Jaa',
#   'Michael Jai White',
#   'Ron Perlman',
#   'Gabriel Dowrick',
#   'Steven Elder',
#   'John Hyams',
#   'Nick Cassidy',
#   'Viktor Dragovic',
#   'Jaa'],
#  ['Ryu Seung-ryong',
#   'Lee Jin-wook',
#   'Yoo Jun-sang',
#   'Kim Sung-ryung',
#   'Yoon Hong-seung',
#   'Chang'],
#  ['Teenage Mutant Ninja Turtles',
#   'Teenage Mutant',
#   'Jonathan Liebesman',
#   'Josh Appelbaum',
#   'André Nemec',
#   'Evan Daugherty',
#   'Megan Fox',
#   'Will Arnett',
#   'William Fichtner',
#   'Danny Woodburn',
#   'Abby Elliott',
#   'Noel Fisher',
#   'Jeremy Howard',
#   'Pete Ploszek',
#   'Alan Ritchson',
#   'Johnny Knoxville',
#   'Tony Shalhoub',
#   'Peter Laird',
#   'Teenage Mutant'],
#  [],
#  ['Tomb Robber', 'Yu Dao'],
#  ['Moon',
#   'Michael Bay',
#   'Ehren Kruger',
#   'Steven Spielberg',
#   'Mark Wahlberg',
#   'Jack Reynor',
#   'Nicola Peltz',
#   'Stanley Tucci',
#   'Kelsey Grammer',
#   'Sophia Myles',
#   'Bingbing Li',
#   'T. J. Miller',
#   'Ehren Kruger'],
#  ['Bryan Singer',
#   'Simon Kinberg',
#   'Jane Goldman',
#   'Matthew Vaughn',
#   'Hugh Jackman',
#   'James McAvoy',
#   'Michael Fassbender',
#   'Jennifer Lawrence',
#   'Halle Berry',
#   'Anna Paquin',
#   'Elliot Page',
#   'Peter Dinklage',
#   'Ian McKellen',
#   'Patrick Stewart',
#   'Chris Claremont',
#   'John Byrne',
#   'Logan',
#   'Oscar'],
#  [],
#  ['Clint Eastwood',
#   'Jason Hall',
#   'Chris Kyle',
#   'Scott McEwen',
#   'Jim DeFelice',
#   'Kyle',
#   'Kyle',
#   'Robert Lorenz',
#   'Andrew Lazar',
#   'Bradley Cooper',
#   'Peter Morgan',
#   'Cooper',
#   'Kyle',
#   'Sienna Miller',
#   'Taya',
#   'Luke Grimes',
#   'Jake McDorman',
#   'Cory Hardrict',
#   'Kevin Lacz',
#   'Navid Negahban',
#   "Keir O'Donnell",
#   'Cooper',
#   'Chris Kyle',
#   'Best Adapted Screenplay'],
#  ['Max Landis',
#   'Jesse Eisenberg',
#   'Kristen Stewart',
#   'Connie Britton',
#   'Walton Goggins',
#   'John Leguizamo',
#   'Bill Pullman',
#   'Tony Hale'],
#  ['Ant-Man',
#   'Scott Lang',
#   'Hank Pym',
#   'Edgar Wright',
#   'Joe Cornish',
#   'Adam McKay',
#   'Paul Rudd',
#   'Rudd',
#   'Scott Lang',
#   'Evangeline Lilly',
#   'Corey Stoll',
#   'Bobby Cannavale',
#   'Michael Peña',
#   'Anthony Mackie',
#   'Wood Harris',
#   'Judy Greer',
#   'David Dastmalchian',
#   'Michael Douglas',
#   'Hank Pym',
#   'Lang',
#   'Ant-Man',
#   'Wright',
#   'Wright',
#   'Cornish',
#   'Wright',
#   'Wright',
#   'Rudd',
#   'Wright',
#   'Wright',
#   'Rudd',
#   'Ant-Man',
#   'Rudd',
#   'Douglas',
#   'Ant-Man',
#   'Ant-Man'],
#  ['Joss Whedon',
#   'Robert Downey Jr.',
#   'Chris Hemsworth',
#   'Mark Ruffalo',
#   'Chris Evans',
#   'Scarlett Johansson',
#   'Jeremy Renner',
#   'Don Cheadle',
#   'Aaron Taylor-Johnson',
#   'Elizabeth Olsen',
#   'Paul Bettany',
#   'Cobie Smulders',
#   'Anthony Mackie',
#   'Hayley Atwell',
#   'Idris Elba',
#   'Stellan Skarsgård',
#   'James Spader',
#   'Samuel L. Jackson'],
#  ['Michael Mann', 'Chris Hemsworth', 'Tang Wei', 'Viola Davis', 'Wang Leehom'],
#  ['Kyle Newman',
#   "John D'Arco",
#   'Hailee Steinfeld',
#   'Jessica Alba',
#   'Dove Cameron',
#   'Samuel L. Jackson'],
#  ['Chappie',
#   'Neill Blomkamp',
#   'Blomkamp',
#   'Terri Tatchell',
#   'Sharlto Copley',
#   'Dev Patel',
#   'Yolandi Visser',
#   'Jose Pablo Cantillo',
#   'Sigourney Weaver',
#   'Chappie'],
#  ['Dragon Blade',
#   'Daniel Lee',
#   'Jackie Chan',
#   'Chan',
#   'Huo An',
#   'Dragon Blade'],
#  ['Josh Trank',
#   'Jeremy Slater',
#   'Simon Kinberg',
#   'Miles Teller',
#   'Michael B. Jordan',
#   'Jamie Bell',
#   'Toby Kebbell',
#   'the Silver Surfer',
#   'Williamsburg Cinemas',
#   'Jon Watts'],
#  ['James Wan',
#   'Chris Morgan',
#   'Vin Diesel',
#   'Paul Walker',
#   'Dwayne Johnson',
#   'Michelle Rodriguez',
#   'Tyrese Gibson',
#   'Chris',
#   'Bridges',
#   'Jordana Brewster',
#   'Kurt Russell',
#   'Dominic Toretto',
#   "Brian O'Conner",
#   'Deckard Shaw',
#   "Paul Walker's",
#   "O'Connor",
#   'Johnson',
#   'Wan',
#   'Walkers',
#   'Caleb',
#   'Cody'],
#  [],
#  ['Scott Mann',
#   'Stephen Cyrus Sepher',
#   'Max Adams',
#   'Robert De Niro',
#   'Jeffrey Dean Morgan',
#   'Kate Bosworth',
#   'Morris Chestnut',
#   'Dave Bautista',
#   'Gina Carano'],
#  ['Aleksander Bach',
#   'Skip Woods',
#   'Michael Finch',
#   'Rupert Friend',
#   'Hannah Ware',
#   'Zachary Quinto',
#   'Thomas Kretschmann'],
#  ['Kingsman',
#   'Matthew Vaughn',
#   'Jane Goldman',
#   'Kingsman',
#   'Mark Millar',
#   'Dave Gibbons',
#   'Gary',
#   'Unwin',
#   'Taron Egerton',
#   'Samuel L. Jackson',
#   'Colin Firth',
#   'Mark Strong',
#   'Michael Caine',
#   'Kingsman',
#   'Kingsman'],
#  ['Guy Ritchie',
#   'Ritchie',
#   'Lionel Wigram',
#   'Norman Felton',
#   'Sam Rolfe',
#   'Henry Cavill',
#   'Armie Hammer',
#   'Alicia Vikander',
#   'Elizabeth Debicki',
#   'Hugh Grant',
#   'John Davis',
#   'Matthew Vaughn',
#   'David Dobkin',
#   'Steven Soderbergh',
#   'Ritchie'],
#  ['Ridley Scott',
#   'Matt Damon',
#   'Drew Goddard',
#   'Andy Weir',
#   'Jessica Chastain',
#   'Jeff Daniels',
#   'Kristen Wiig',
#   'Sean Bean',
#   'Michael Peña',
#   'Kate Mara',
#   'Sebastian Stan',
#   'Aksel Hennie',
#   'Mackenzie Davis',
#   'Donald Glover',
#   'Benedict Wong',
#   'Simon Kinberg',
#   'Drew Goddard',
#   'Wadi Rum',
#   'Comedy',
#   'Comedy'],
#  ['George Miller',
#   'Miller',
#   'Brendan McCarthy',
#   'Nico Lathouris',
#   'Village Roadshow Pictures',
#   'Kennedy Miller Mitchell',
#   'Tom Hardy',
#   'Nicholas Hoult',
#   'Hugh Keays-Byrne',
#   'Rosie Huntington-Whiteley',
#   'Riley Keough',
#   'Zoë Kravitz',
#   'Abbey Lee',
#   'Courtney Eaton',
#   'Max Rockatansky',
#   'Furiosa',
#   'Immortan Joe',
#   'Miller',
#   'Miller',
#   'Happy Feet',
#   'Max',
#   'Mad Max',
#   'Best Makeup',
#   'Best Film Editing',
#   'Miller',
#   'Furiosa',
#   'Miller'],
#  [],
#  ['David Koepp',
#   'Eric Aronson',
#   'Mortdecai',
#   'Kyril Bonfiglioli',
#   'Johnny Depp',
#   'Gwyneth Paltrow',
#   'Ewan McGregor',
#   'Olivia Munn',
#   'Paul Bettany',
#   'Jeff Goldblum',
#   'Mortdecai'],
#  ['John Erick Dowdle', 'Drew Dowdle', 'Owen Wilson', 'Pierce Brosnan'],
#  ['Ericson Core',
#   'Kurt Wimmer',
#   'John Baldecchi',
#   'Broderick Johnson',
#   'Andrew A. Kosove',
#   'Christopher Taylor',
#   'David Valdes',
#   'Édgar Ramírez',
#   'Luke Bracey',
#   'Teresa Palmer',
#   'Delroy Lindo',
#   'Ray Winstone',
#   'RealD'],
#  ['Jaume Collet-Serra',
#   'Brad Ingelsby',
#   'Liam Neeson',
#   'Joel Kinnaman',
#   'Ed Harris',
#   'Liam Neeson',
#   'Jaume Collet-Serra'],
#  ['Brad Peyton',
#   'Carlton Cuse',
#   'Andre Fabrizio',
#   'Jeremy Passmore',
#   'Dwayne Johnson',
#   'Carla Gugino',
#   'Alexandra Daddario',
#   'Ioan Gruffudd',
#   'Archie Panjabi',
#   'Paul Giamatti',
#   'Johnson'],
#  ['James McTeigue',
#   'Milla Jovovich',
#   'Robert Forster',
#   'Angela Bassett',
#   'Roger Rees',
#   'Antonia Thomas',
#   "James D'Arcy",
#   "Genevieve O'Reilly",
#   'Dylan McDermott'],
#  ['Spectre',
#   'James Bond',
#   'Daniel Craig',
#   'James Bond',
#   'Sam Mendes',
#   'John Logan',
#   'Neal Purvis',
#   'Robert Wade',
#   'Jez Butterworth',
#   'Spectre',
#   'Ernst Stavro',
#   'Christoph Waltz',
#   'Blofeld',
#   'Thunderball',
#   'James Bond',
#   'Eve Moneypenny',
#   'Léa Seydoux',
#   'Madeleine Swann',
#   'Dave Bautista',
#   'Hinx',
#   'Andrew Scott',
#   'Max Denbigh',
#   'Monica Bellucci',
#   'Lucia Sciarra',
#   'Spectre',
#   'Spectre',
#   'Spectre',
#   'Albert Hall',
#   'Sam Smith',
#   'Spectre',
#   'Craig'],
#  ['Paul Feig',
#   'Melissa McCarthy',
#   'Rose Byrne',
#   'Miranda Hart',
#   'Bobby Cannavale',
#   'Allison Janney',
#   'Jude Law',
#   'Susan Cooper',
#   'McCarthy',
#   'Peter Chernin',
#   'Jenno Topping',
#   'Jessie Henderson',
#   'Comedy'],
#  ['J. J. Abrams',
#   'Rey',
#   'Finn',
#   'Poe Dameron',
#   'Luke Skywalker',
#   'Resistance',
#   'Harrison Ford',
#   'Mark Hamill',
#   'Carrie Fisher',
#   'Adam Driver',
#   'Daisy Ridley',
#   'John Boyega',
#   'Oscar Isaac',
#   'Andy Serkis',
#   'Domhnall Gleeson',
#   'Anthony Daniels',
#   'Peter Mayhew',
#   'Max von Sydow',
#   'George Lucas',
#   'Bryan Burk',
#   'Kathleen Kennedy',
#   'Abrams',
#   'Lawrence Kasdan',
#   'Michael Arndt',
#   'John Williams'],
#  ['Olivier Megaton',
#   'Luc Besson',
#   'Robert Mark Kamen',
#   'Taken',
#   'Liam Neeson',
#   'Forest Whitaker',
#   'Maggie Grace',
#   'Famke Janssen'],
#  ['Camille Delamarre',
#   'Bill Collage',
#   'Adam Cooper',
#   'Luc Besson',
#   'Ed Skrein',
#   'Jason Statham',
#   'Frank Martin',
#   'François Berléand'],
#  ['Alan Taylor',
#   'Laeta Kalogridis',
#   'Patrick Lussier',
#   'Arnold Schwarzenegger',
#   'Jason Clarke',
#   'Emilia Clarke',
#   'Jai Courtney',
#   'J. K. Simmons',
#   'Matt Smith',
#   'Courtney B. Vance',
#   'Michael Gladis',
#   'Lee Byung-hun',
#   'Kyle Reese',
#   'Sarah Connor',
#   'Kyle',
#   'Sarah',
#   'Megan Ellison',
#   'David',
#   'James Cameron',
#   'Legacy Effects'],
#  ['Wild Card',
#   'Simon West',
#   'Jason Statham',
#   'Michael Angarano',
#   'Dominik Garcia-Lorido',
#   'Milo Ventimiglia',
#   'Davis',
#   'Stanley Tucci',
#   'William Goldman',
#   'Burt Reynolds',
#   'Wild Card'],
#  [],
#  ['Z Airando', 'Hiroshi Shinagawa'],
#  ["Gavin O'Connor",
#   'Bill Dubuque',
#   'Ben Affleck',
#   'Anna Kendrick',
#   'J. K. Simmons',
#   'Jon Bernthal',
#   'Cynthia Addai-Robinson',
#   'Jeffrey Tambor',
#   'John Lithgow',
#   'Christian Wolff'],
#  ['Creed',
#   'Justin Kurzel',
#   'Michael Lesslie',
#   'Adam Cooper',
#   'Bill Collage',
#   'Michael Fassbender',
#   'Jeremy Irons',
#   'Brendan Gleeson',
#   'Charlotte Rampling',
#   'Michael K. Williams',
#   'Callum Lynch',
#   'Animus',
#   'Aguilar de Nerha',
#   'Creed'],
#  ['Superman',
#   'Cruel',
#   'Unusual Films',
#   'Zack Snyder',
#   'Chris Terrio',
#   'David S. Goyer',
#   'Ben Affleck',
#   'Henry Cavill',
#   'Amy Adams',
#   'Jesse Eisenberg',
#   'Diane Lane',
#   'Laurence Fishburne',
#   'Jeremy Irons',
#   'Holly Hunter',
#   'Gal Gadot',
#   'Batman',
#   'Superman',
#   'Lex Luthor',
#   'Batman',
#   'Superman',
#   'Luthor',
#   'Frank Miller',
#   'Batman',
#   'Affleck'],
#  ['America',
#   'America',
#   'Anthony',
#   'Joe Russo',
#   'Christopher Markus',
#   'Stephen McFeely',
#   'Chris Evans',
#   'Steve Rogers',
#   'Robert Downey Jr.',
#   'Scarlett Johansson',
#   'Sebastian Stan',
#   'Anthony Mackie',
#   'Don Cheadle',
#   'Jeremy Renner',
#   'Chadwick Boseman',
#   'Paul Bettany',
#   'Elizabeth Olsen',
#   'Paul Rudd',
#   'Tom Holland',
#   'Frank Grillo',
#   'William Hurt',
#   'Daniel Brühl',
#   'Steve Rogers',
#   'Tony Stark',
#   'Markus',
#   'Evans',
#   'Sam Wilson'],
#  ['Scott Derrickson',
#   'Jon Spaihts',
#   'C. Robert Cargill',
#   'Benedict Cumberbatch',
#   'Stephen Strange',
#   'Rachel McAdams',
#   'Benedict Wong',
#   'Michael Stuhlbarg',
#   'Benjamin Bratt',
#   'Scott Adkins',
#   'Mads Mikkelsen',
#   'Tilda Swinton',
#   'Thomas Dean Donnelly',
#   'Joshua Oppenheimer',
#   'Derrickson',
#   'Derrickson',
#   'Cargill'],
#  ['Tim Miller',
#   'Rhett Reese',
#   'Paul Wernick',
#   'Ryan Reynolds',
#   'Morena Baccarin',
#   'Ed Skrein',
#   'T. J. Miller',
#   'Gina Carano',
#   'Brianna Hildebrand',
#   'Wade Wilson',
#   'Reynolds',
#   'Reynolds',
#   'Miller',
#   'Reynolds',
#   'gore'],
#  ['Dean Devlin',
#   'Nicolas Wright',
#   'James A. Woods',
#   'James Vanderbilt',
#   'Jeff Goldblum',
#   'Liam Hemsworth',
#   'Bill Pullman',
#   'Maika Monroe',
#   'Travis Tope',
#   'William Fichtner',
#   'Judd Hirsch',
#   "Robert Loggia's",
#   'IMAX 3D'],
#  ['Jack Reacher',
#   'Edward Zwick',
#   'Zwick',
#   'Richard Wenk',
#   'Marshall Herskovitz',
#   'Lee Child',
#   'Jack Reacher',
#   'Tom Cruise',
#   'Cobie Smulders',
#   'Patrick Heusinger',
#   'Aldis Hodge',
#   'Danika Yarosh',
#   'Robert Knepper',
#   'Cruise'],
#  ['Jason Bourne',
#   'Paul Greengrass',
#   'Christopher Rouse',
#   'The Bourne Ultimatum',
#   'Matt Damon',
#   'Jason Bourne',
#   'Tommy Lee Jones',
#   'Alicia Vikander',
#   'Vincent Cassel',
#   'Riz Ahmed',
#   'Ato Essandoh',
#   'Scott Shepherd',
#   'Aaron Cross',
#   'Greengrass',
#   'Jeremy Renner',
#   'Jason Bourne',
#   'Bourne',
#   'Robert Dewey',
#   'Heather Lee',
#   'Jason Bourne'],
#  ['Greg Mottola', 'Michael LeSieur', 'Isla Fisher'],
#  ['David Yates',
#   'Edgar Rice Burroughs',
#   'Alexander Skarsgård',
#   'Samuel L. Jackson',
#   'Margot Robbie',
#   'Jim Broadbent',
#   'Christoph Waltz',
#   'John Clayton',
#   'George Washington Williams'],
#  ['Babak Najafi',
#   'Katrin Benedikt',
#   'Chad St. John',
#   'Christian Gudegast',
#   "Antoine Fuqua's",
#   'Gerard Butler',
#   'Aaron Eckhart',
#   'Alon Moni Aboutboul',
#   'Angela Bassett',
#   'Robert Forster',
#   'Jackie Earle Haley',
#   'Melissa Leo',
#   'Radha Mitchell',
#   "Sean O'Bryan",
#   'Waleed Zuaiter',
#   'Charlotte Riley',
#   'Mike Banning',
#   'Benjamin Asher',
#   'Gramercy Pictures'],
#  ['Max Steel',
#   'Dolphin Films',
#   'Stewart Hendler',
#   'Christopher Yost',
#   'Ben Winchell',
#   'Josh Brener',
#   'Ana Villafañe',
#   'Andy García',
#   'Maria Bello',
#   'Billy Slaughter',
#   'Max McGrath',
#   'Max Steel'],
#  ['Dennis Gansel',
#   'Tony Mosher',
#   'Jason Statham',
#   'Tommy Lee Jones',
#   'Jessica Alba',
#   'Michelle Yeoh'],
#  ['Tim Story',
#   'Phil Hay',
#   'Matt Manfredi',
#   'Kevin Hart',
#   'Ken Jeong',
#   'Benjamin Bratt',
#   'Olivia Munn',
#   'Bruce McGill',
#   'Tika Sumpter'],
#  ['Justin Lin',
#   'Simon Pegg',
#   'Doug Jung',
#   'Gene Roddenberry',
#   'Chris Pine',
#   'Zachary Quinto',
#   'James T. Kirk',
#   'Karl Urban',
#   'Zoe Saldana',
#   'John Cho',
#   'Anton Yelchin',
#   'Idris Elba',
#   'Sofia Boutella',
#   'Joe Taslim',
#   'Leonard Nimoy',
#   'Lin',
#   'Best Makeup'],
#  ['David Ayer',
#   'Will Smith',
#   'Jared Leto',
#   'Margot Robbie',
#   'Joel Kinnaman',
#   'Viola Davis',
#   'Jai Courtney',
#   'Jay Hernandez',
#   'Adewale Akinnuoye-Agbaje',
#   'Scott Eastwood',
#   'Ike Barinholtz',
#   'Cara Delevingne',
#   'Suicide Squad',
#   'Robbie',
#   'Davis',
#   'Courtney'],
#  [],
#  ['Bryan Singer',
#   'Simon Kinberg',
#   'Michael Dougherty',
#   'Dan Harris',
#   'James McAvoy',
#   'Michael Fassbender',
#   'Jennifer Lawrence',
#   'Oscar Isaac',
#   'Nicholas Hoult',
#   'Rose Byrne',
#   'Tye Sheridan',
#   'Olivia Munn',
#   'Harris',
#   'Dark Phoenix'],
#  ['Atomic Blonde',
#   'David Leitch',
#   'Kurt Johnstad',
#   'Charlize Theron',
#   'James McAvoy',
#   'John Goodman',
#   'Til Schweiger',
#   'Eddie Marsan',
#   'Sofia Boutella',
#   'Roland Møller',
#   'Atomic Blonde',
#   'John Wick',
#   'Leitch'],
#  ['Baby Driver',
#   'Edgar Wright',
#   'Ansel Elgort',
#   'Debora',
#   'Kevin Spacey',
#   'Jon Hamm',
#   'Eiza González',
#   'Jamie Foxx',
#   'Jon Bernthal',
#   'Eric Fellner',
#   'Tim Bevan',
#   'Baby Driver',
#   'Wright',
#   'Baby Driver',
#   'Wright',
#   'Baby Driver',
#   'Baby Driver',
#   'Baby Driver'],
#  ['Michael Berk',
#   'Douglas Schwartz',
#   'Gregory J. Bonann',
#   'Seth Gordon',
#   'Mark Swift',
#   'Jay Scherick',
#   'David Ronn',
#   'Thomas Lennon',
#   'Robert Ben Garant',
#   'Dwayne Johnson',
#   'Zac Efron',
#   'Jon Bass',
#   'Alexandra Daddario',
#   'Kelly Rohrbach',
#   'David Hasselhoff',
#   'Mitch Buchannon',
#   'Johnson'],
#  ['Hepburn',
#   'Takuya Kimura',
#   'Hana Sugisaki',
#   'Takashi Miike',
#   'Hiroaki Samura',
#   'Manji',
#   'Kimura',
#   'Rin Asano',
#   'Manji',
#   'Kimura',
#   'Manji'],
#  ['James Gunn',
#   'Chris Pratt',
#   'Zoe Saldaña',
#   'Dave Bautista',
#   'Vin Diesel',
#   'Bradley Cooper',
#   'Michael Rooker',
#   'Karen Gillan',
#   'Pom Klementieff',
#   'Elizabeth Debicki',
#   'Chris Sullivan',
#   'Sean Gunn',
#   'Sylvester Stallone',
#   'Kurt Russell',
#   'Peter Quill',
#   "James Gunn's",
#   'James Gunn',
#   'Russell'],
#  ['Patrick Hughes',
#   'Ryan Reynolds',
#   'Samuel L. Jackson',
#   'Gary Oldman',
#   'Jackson',
#   'Reynolds',
#   'Jackson'],
#  ['John Wick',
#   'John Wick 2',
#   'Chad Stahelski',
#   'Derek Kolstad',
#   'John Wick',
#   'John Wick',
#   'Keanu Reeves',
#   'Laurence Fishburne',
#   'Riccardo Scamarcio',
#   'John Leguizamo',
#   'Ian McShane',
#   'John Wick',
#   'Reeves',
#   'John Wick'],
#  ['DC Films',
#   'Cruel',
#   'Batman',
#   'Zack Snyder',
#   'Chris Terrio',
#   'Joss Whedon',
#   'Ben Affleck',
#   'Henry Cavill',
#   'Amy Adams',
#   'Ezra Miller',
#   'Jason Momoa',
#   'Ray Fisher',
#   'Jeremy Irons',
#   'Diane Lane',
#   'Connie Nielsen',
#   'J. K. Simmons',
#   'Ciarán Hinds',
#   'Flash',
#   'Superman',
#   'George Miller',
#   'Terrio',
#   "Zack Snyder's"],
#  ['Kingsman',
#   'Matthew Vaughn',
#   'Jane Goldman',
#   'Kingsman',
#   'Mark Millar',
#   'Dave Gibbons',
#   'Colin Firth',
#   'Taron Egerton',
#   'Mark Strong',
#   'Edward Holcroft',
#   'Julianne Moore',
#   'Halle Berry',
#   'Pedro Pascal',
#   'Elton John',
#   'Channing Tatum',
#   'Jeff Bridges',
#   'Kingsman',
#   'Poppy Adams',
#   'Kingsman'],
#  ['Jordan Vogt-Roberts',
#   'Tom Hiddleston',
#   'Samuel L. Jackson',
#   'John Goodman',
#   'Brie Larson',
#   'Toby Kebbell',
#   'John Ortiz',
#   'Corey Hawkins',
#   'Jason Mitchell',
#   'Shea Whigham',
#   'Thomas Mann',
#   'Terry Notary',
#   'John C. Reilly',
#   'Kong',
#   'Godzilla',
#   'Jackson',
#   'Reilly',
#   'Godzilla',
#   'Kong'],
#  ['Logan',
#   'Hugh Jackman',
#   'Mark Millar',
#   'Steve McNiven',
#   'Charles Xavier',
#   'Laura',
#   'Donald Pierce',
#   'Zander Rice',
#   'James Mangold',
#   'Michael Green',
#   'Scott Frank',
#   'Patrick Stewart',
#   'Richard E. Grant',
#   'Boyd Holbrook',
#   'Stephen Merchant',
#   'Dafne Keen',
#   'Stewart',
#   'X.'],
#  ['Antonio Negret',
#   'Michael Brandt',
#   'Derek Haas',
#   'Pierre Morel',
#   'Michael Brandt',
#   'Derek Haas',
#   'Scott Eastwood',
#   'Ana de Armas',
#   'Gaia Weiss'],
#  ['John Gatins',
#   'Naomi Scott',
#   'Ludi Lin',
#   'David Denman',
#   'Bill Hader',
#   'Bryan Cranston',
#   'Elizabeth Banks',
#   'Haim Saban',
#   'Saban'],
#  ['Baran bo Odar',
#   'Andrea Berloff',
#   'Sleepless Night',
#   'Jamie Foxx',
#   'Michelle Monaghan',
#   'Dermot Mulroney',
#   'David Harbour'],
#  ['Spider-Man',
#   'Jon Watts',
#   'Jonathan Goldstein',
#   'John Francis Daley',
#   'Christopher Ford',
#   'Chris McKenna',
#   'Erik Sommers',
#   'Tom Holland',
#   'Peter Parker / Spider-Man',
#   'Michael Keaton',
#   'Jon Favreau',
#   'Gwyneth Paltrow',
#   'Zendaya',
#   'Donald Glover',
#   'Jacob Batalon',
#   'Laura Harrier',
#   'Tony Revolori',
#   'Bokeem Woodbine',
#   'Tyne Daly',
#   'Marisa Tomei',
#   'Robert Downey Jr.',
#   'Peter Parker',
#   'Spider',
#   'Keaton',
#   'Downey',
#   'Tony Stark /',
#   'Spider',
#   'Spider'],
#  ['Jedi',
#   'Rian Johnson',
#   'Mark Hamill',
#   'Carrie Fisher',
#   'Adam Driver',
#   'Daisy Ridley',
#   'John Boyega',
#   'Oscar Isaac',
#   'Andy Serkis',
#   'Domhnall Gleeson',
#   'Anthony Daniels',
#   'Gwendoline Christie',
#   'Kelly Marie Tran',
#   'Laura Dern',
#   'Jedi',
#   'Rey',
#   'Luke Skywalker',
#   'Leia Organa',
#   'Finn',
#   'Jedi',
#   'Kathleen Kennedy',
#   'Ram Bergman',
#   'J. J. Abrams',
#   'John Williams',
#   'Skellig Michael'],
#  ['Thor',
#   'Taika Waititi',
#   'Eric Pearson',
#   'Craig Kyle',
#   'Christopher Yost',
#   'Chris Hemsworth',
#   'Tom Hiddleston',
#   'Cate Blanchett',
#   'Idris Elba',
#   'Jeff Goldblum',
#   'Tessa Thompson',
#   'Karl Urban',
#   'Mark Ruffalo',
#   'Anthony Hopkins',
#   'Hela',
#   'Blanchett',
#   'Kyle',
#   'Hiddleston',
#   'Alan Taylor',
#   'Ruffalo',
#   'Blanchett',
#   'Waititi'],
#  ['Michael Bay',
#   'Mark Wahlberg',
#   'Josh Duhamel',
#   'John Turturro',
#   'Glenn Morshower',
#   'Laura Haddock',
#   'Isabela Moner',
#   'Jerrod Carmichael',
#   'Santiago Cabrera',
#   'Anthony Hopkins'],
#  ['Anna Foerster',
#   'Kate Beckinsale',
#   'Theo James',
#   'Peter Andersson',
#   'James Faulkner',
#   'Clementine Nicholson',
#   'Daisy Head',
#   'Oliver Stark',
#   'Charles Dance'],
#  ['Cruel',
#   'Unusual Films',
#   'Patty Jenkins',
#   'Allan Heinberg',
#   'Heinberg',
#   'Zack Snyder',
#   'Chris Pine',
#   'Robin Wright',
#   'Danny Huston',
#   'David Thewlis',
#   'Connie Nielsen',
#   'Wonder Woman',
#   'Wonder Woman',
#   'Diana',
#   'Steve Trevor',
#   'Ivan Reitman',
#   'Jon Cohen',
#   'Todd Alcott',
#   'Joss Whedon',
#   'Jenkins',
#   "William Moulton Marston's",
#   "George Pérez's",
#   'Wonder Woman',
#   'RealD 3D',
#   'Jenkins',
#   'Wright'],
#  []]

# %%
statements
# Out:
# ['13_Assassins_(2010_film) is directed by Takashi Miike.',
#  '14_Blades is directed by Daniel Lee.',
#  '22_Bullets is directed by Richard Berry.',
#  'Alien_vs_Ninja is directed by Seiji Chiba.',
#  'Bad_Blood_(2010_film) is directed by Dennis Law.',
#  'Blades_of_Blood is directed by Lee Joon-ik.',
#  'The_Book_of_Eli is directed by Gary Whitta.',
#  'The_Bounty_Hunter_(2010_film) is directed by Andy Tennant.',
#  'The_Butcher,_the_Chef_and_the_Swordsman is directed by Wuershan.',
#  'Centurion_(film) is directed by Neil Marshall.',
#  'The_Crazies_(2010_film) is directed by Breck Eisner.',
#  'Date_Night is directed by Shawn Levy.',
#  'The_Expendables_(2010_film) is directed by Jason Statham.',
#  'Faster_(2010_film) is directed by George Tillman Jr..',
#  'Fire_of_Conscience is directed by Dante Lam.',
#  'From_Paris_with_Love_(film) is directed by Pierre Morel.',
#  'Gallants_(film) is directed by Derek Kwok.',
#  'Gothic_%26_Lolita_Psycho is directed by Gosu Rori Shokeinin.',
#  'Inception is directed by Christopher Nolan.',
#  'Ip_Man_2 is directed by Wilson Yip.',
#  'Just_Call_Me_Nobody is directed by Kevin Chu.',
#  'Kick-Ass_(film) is directed by Matthew Vaughn.',
#  'Killers_(2010_film) is directed by Robert Luketic.',
#  'Knight_and_Day is directed by James Mangold.',
#  'Let_the_Bullets_Fly is directed by Jiang Wen.',
#  'Little_Big_Soldier is directed by Ding Sheng.',
#  'MacGruber_(film) is directed by Will Forte.',
#  'Machete_(2010_film) is directed by Robert Rodriguez.',
#  'Ong_Bak_3 is directed by Tony Jaa.',
#  'Operation:_Endgame is directed by Fouad Mikati.',
#  'Predators_(film) is directed by Nimród Antal.',
#  'The_Red_Eagle is directed by Wisit Sasanatieng.',
#  'Reign_of_Assassins is directed by Su Chao-pin.',
#  'Repo_Men is directed by Miguel Sapochnik.',
#  'Salt_(2010_film) is directed by Phillip Noyce.',
#  'Scott_Pilgrim_vs._the_World is directed by Edgar Wright.',
#  'Shank_(2010_film) is directed by Mo Ali.',
#  'Smokin%27_Aces_2:_Assassins%27_Ball is directed by Tom Berenger.',
#  'The_Spy_Next_Door is directed by Brian Levant.',
#  'Stake_Land is directed by Jim Mickle.',
#  'The_Stool_Pigeon_(2010_film) is directed by Dante Lam.',
#  'Triple_Tap is directed by Derek Yee.',
#  'True_Legend is directed by Yuen Woo-ping.',
#  'Unstoppable_(2010_film) is directed by Tony Scott.',
#  'The_Warrior%27s_Way is directed by Sngmoo Lee.',
#  'The_Yellow_Sea_(film) is directed by Na Hong-jin.',
#  '30_Minutes_or_Less is directed by Ruben Fleischer.',
#  'Attack_the_Block is directed by Joe Cornish.',
#  'Battle:_Los_Angeles is directed by Jonathan Liebesman.',
#  'Battlefield_Heroes_(film) is directed by Lee Joon-ik.',
#  'Bbuddah..._Hoga_Terra_Baap is directed by Puri Jagannadh.',
#  'Singham is directed by Rohit Shetty.',
#  'Bodyguard_(2011_Hindi_film) is directed by Atul Agnihotri.',
#  'Captain_America:_The_First_Avenger is directed by Joe Johnston.',
#  'The_Darkest_Hour_(film) is directed by Chris Gorak.',
#  'Drive_Angry is directed by Patrick Lussier.',
#  'Fast_Five is directed by Justin Lin.',
#  'Flying_Swords_of_Dragon_Gate is directed by Tsui Hark.',
#  'Hanna_(film) is directed by Joe Wright.',
#  'He-Man_(film) is directed by Ding Sheng.',
#  'Hobo_with_a_Shotgun is directed by Jason Eisener.',
#  'I_Am_Number_Four_(film) is directed by D. J. Caruso.',
#  'Karate_Girl is directed by Yoshikatsu Kimura.',
#  'Karate-Robo_Zaborgar is directed by Noboru Iguchi.',
#  'The_Kick_(film) is directed by Prachya Pinkaew.',
#  'Killer_Elite_(film) is directed by Gary McKendry.',
#  'Kung_Fu_Panda_2 is directed by Frozen.',
#  'A_Lonely_Place_to_Die is directed by Julian Gilbey.',
#  'The_Lost_Bladesman is directed by Alan Mak.',
#  'The_Mechanic_(2011_film) is directed by Simon West.',
#  'Mission:_Impossible_%E2%80%93_Ghost_Protocol is directed by Brad Bird.',
#  'Mr._%26_Mrs._Incredible is directed by Vincent Kok.',
#  'My_Own_Swordsman is directed by Shang Jing.',
#  'Ninja_Kids!!! is directed by Takashi Miike.',
#  'No_Limit_(2011_film) is directed by Fu Huayang.',
#  'Red_Tears is directed by Takanori Tsujimoto.',
#  'Season_of_the_Witch_(2011_film) is directed by Dominic Sena.',
#  'Sector_7_(film) is directed by Kim Ji-hoon.',
#  'Shaolin_(film) is directed by Benny Chan.',
#  'Sherlock_Holmes:_A_Game_of_Shadows is directed by Guy Ritchie.',
#  'Sleepless_Night_(2011_film) is directed by Frédéric Jardin.',
#  'Source_Code is directed by Duncan Jones.',
#  'The_Sword_Identity is directed by Xu Haofeng.',
#  'Sucker_Punch_(2011_film) is directed by Zack Snyder.',
#  'Thor_(film) is directed by Kenneth Branagh.',
#  'Transformers:_Dark_of_the_Moon is directed by Michael Bay.',
#  'The_Warring_States_(film) is directed by Chen Jin.',
#  'White_Vengeance is directed by Daniel Lee.',
#  'X-Men:_First_Class is directed by Matthew Vaughn.',
#  'Yakuza_Weapon is directed by Ken Ishikawa.',
#  '21_Jump_Street_(film) is directed by Phil.',
#  'Agneepath_(2012_film) is directed by Karan Johar.',
#  'The_Avengers_(2012_film) is directed by Joss Whedon.',
#  'Bait_3D is directed by John Kim.',
#  'Battleship_(film) is directed by Peter Berg.',
#  'Black_%26_White_Episode_I:_The_Dawn_of_Assault is directed by Tsai Yueh-hsun.',
#  'The_Bourne_Legacy_(film) is directed by Tony Gilroy.',
#  'Contraband_(2012_film) is directed by Baltasar Kormákur.',
#  'CZ12 is directed by Jackie Chan.',
#  'Dabangg_2 is directed by Arbaaz Khan.',
#  'The_Dark_Knight_Rises is directed by Christopher Nolan.',
#  'The_Expendables_2 is directed by Simon West.',
#  'Fire_with_Fire_(2012_film) is directed by David Barrett.',
#  'The_Four_(film) is directed by Gordon Chan.',
#  'Ghost_Rider:_Spirit_of_Vengeance is directed by Mark Neveldine.',
#  'The_Guillotines is directed by Andrew Lau.',
#  'Guns_and_Roses_(2012_film) is directed by Ning Hao.',
#  'Jack_Reacher_(film) is directed by Christopher McQuarrie.',
#  'John_Carter_(film) is directed by Andrew Stanton.',
#  'The_Man_with_the_Iron_Fists is directed by Roth.',
#  'Naked_Soldier is directed by Marco Mak.',
#  'Premium_Rush is directed by David Koepp.',
#  'Safe_House_(2012_film) is directed by Daniel Espinosa.',
#  'Skyfall is directed by Sam Mendes.',
#  'Tai_Chi_0 is directed by Stephen Fung.',
#  'Taken_2 is directed by Olivier Megaton.',
#  'Underworld:_Awakening is directed by Måns Mårlind.',
#  'Universal_Soldier:_Day_of_Reckoning is directed by John Hyams.',
#  'The_Viral_Factor is directed by Dante Lam.',
#  'Wu_Dang_(film) is directed by Patrick Leung.',
#  '2_Guns is directed by Baltasar Kormákur.',
#  'Angel_Warriors is directed by Fu Huayang.',
#  'The_Berlin_File is directed by Ryoo Seung-wan.',
#  'Bullet_to_the_Head is directed by Walter Hill.',
#  'Elysium_(film) is directed by Neill Blomkamp.',
#  'Ender%27s_Game_(film) is directed by Gavin Hood.',
#  'Escape_Plan_(film) is directed by Mikael Håfström.',
#  'Fast_%26_Furious_6 is directed by Justin Lin.',
#  'The_Four_II is directed by Gordon Chan.',
#  'Gangster_Squad_(film) is directed by Ruben Fleischer.',
#  'A_Good_Day_to_Die_Hard is directed by John Moore.',
#  'The_Heat_(film) is directed by Paul Feig.',
#  'Hummingbird_(film) is directed by Steven Knight.',
#  'Iron_Man_3 is directed by Drew Pearce.',
#  'Kick-Ass_2_(film) is directed by Jeff Wadlow.',
#  'The_Last_Stand_(2013_film) is directed by Kim Jee-woon.',
#  'The_Lone_Ranger_(2013_film) is directed by Gore Verbinski.',
#  'Machete_Kills is directed by Robert Rodriguez.',
#  'Man_of_Steel_(film) is directed by Zack Snyder.',
#  'Oblivion_(2013_film) is directed by Joseph Kosinski.',
#  'Olympus_Has_Fallen is directed by Antoine Fuqua.',
#  'Once_Upon_a_Time_in_Vietnam is directed by Dustin Nguyen.',
#  'Pain_%26_Gain is directed by Michael Bay.',
#  'Star_Trek_Into_Darkness is directed by J. J. Abrams.',
#  'The_Suspect_(2013_South_Korean_film) is directed by Won Shin-yun.',
#  'Switch_(2013_film) is directed by Jay Sun.',
#  'Thor:_The_Dark_World is directed by Alan Taylor.',
#  'Tom_Yum_Goong_2 is directed by Prachya Pinkaew.',
#  'Welcome_to_the_Punch is directed by Eran Creevy.',
#  'White_House_Down is directed by James Vanderbilt.',
#  'The_Wolverine_(film) is directed by Logan.',
#  'World_War_Z_(film) is directed by Marc Forster.',
#  '22_Jump_Street is directed by Phil.',
#  'The_Amazing_Spider-Man_2 is directed by Marc Webb.',
#  'Black_%26_White:_The_Dawn_of_Justice is directed by Tsai Yueh-Hsun.',
#  'Brick_Mansions is directed by Camille Delamarre.',
#  'Brotherhood_of_Blades is directed by Lu Yang.',
#  'Captain_America:_The_Winter_Soldier is directed by Anthony.',
#  'The_Dead_Lands is directed by Toa Fraser.',
#  'Everly_(film) is directed by Joe Lynch.',
#  'The_Expendables_3 is directed by Patrick Hughes.',
#  'Gun_Woman is directed by Asami Sugiura.',
#  'High_Kick_Angels is directed by Kazuhiro Yokoyama.',
#  'Jack_Ryan:_Shadow_Recruit is directed by Kenneth Branagh.',
#  'John_Wick_(film) is directed by Chad Stahelski.',
#  'The_Legend_of_Hercules is directed by Renny Harlin.',
#  'Kung_Fu_Jungle is directed by Teddy Chan.',
#  'Lucy_(2014_film) is directed by Lucy.',
#  'Mercenaries_(2014_film) is directed by Christopher Ray.',
#  'Ride_Along_(film) is directed by Tim Story.',
#  'RoboCop_(2014_film) is directed by José Padilha.',
#  'Skin_Trade_(film) is directed by Dolph Lundgren.',
#  'The_Target_(film) is directed by Yoon Hong-seung.',
#  'Teenage_Mutant_Ninja_Turtles_(2014_film) is directed by Teenage Mutant Ninja Turtles.',
#  'Tomb_Robber is directed by Yu Dao.',
#  'Transformers:_Age_of_Extinction is directed by Michael Bay.',
#  'X-Men:_Days_of_Future_Past is directed by Bryan Singer.',
#  'American_Sniper is directed by Clint Eastwood.',
#  'American_Ultra is directed by Max Landis.',
#  'Ant-Man_(film) is directed by Edgar Wright.',
#  'Avengers:_Age_of_Ultron is directed by Joss Whedon.',
#  'Blackhat_(film) is directed by Michael Mann.',
#  'Barely_Lethal is directed by Kyle Newman.',
#  'Chappie_(film) is directed by Neill Blomkamp.',
#  'Dragon_Blade_(film) is directed by Daniel Lee.',
#  'Furious_7 is directed by James Wan.',
#  'Heist_(2015_film) is directed by Scott Mann.',
#  'Hitman:_Agent_47 is directed by Aleksander Bach.',
#  'Kingsman:_The_Secret_Service is directed by Matthew Vaughn.',
#  'The_Man_from_U.N.C.L.E._(film) is directed by Guy Ritchie.',
#  'The_Martian_(film) is directed by Ridley Scott.',
#  'Mad_Max:_Fury_Road is directed by George Miller.',
#  'Mortdecai_(film) is directed by David Koepp.',
#  'No_Escape_(2015_film) is directed by John Erick Dowdle.',
#  'Point_Break_(2015_film) is directed by Ericson Core.',
#  'Run_All_Night_(film) is directed by Jaume Collet-Serra.',
#  'San_Andreas_(film) is directed by Brad Peyton.',
#  'Survivor_(film) is directed by James McTeigue.',
#  'Spectre_(2015_film) is directed by Sam Mendes.',
#  'Spy_(2015_film) is directed by Paul Feig.',
#  'Star_Wars:_The_Force_Awakens is directed by J. J. Abrams.',
#  'Taken_3 is directed by Olivier Megaton.',
#  'The_Transporter_Refueled is directed by Camille Delamarre.',
#  'Terminator_Genisys is directed by Alan Taylor.',
#  'Wild_Card_(2015_film) is directed by Simon West.',
#  'Z_Island is directed by Hiroshi Shinagawa.',
#  "The_Accountant_(2016_film) is directed by Gavin O'Connor.",
#  'Assassin%27s_Creed_(film) is directed by Justin Kurzel.',
#  'Batman_v_Superman:_Dawn_of_Justice is directed by Zack Snyder.',
#  'Captain_America:_Civil_War is directed by Anthony.',
#  'Doctor_Strange_(2016_film) is directed by Scott Derrickson.',
#  'Independence_Day:_Resurgence is directed by Dean Devlin.',
#  'Jack_Reacher:_Never_Go_Back is directed by Edward Zwick.',
#  'Jason_Bourne_(film) is directed by Paul Greengrass.',
#  'Keeping_Up_with_the_Joneses_(film) is directed by Greg Mottola.',
#  'The_Legend_of_Tarzan_(film) is directed by David Yates.',
#  'London_Has_Fallen is directed by Babak Najafi.',
#  'Mechanic:_Resurrection is directed by Dennis Gansel.',
#  'Ride_Along_2 is directed by Tim Story.',
#  'Star_Trek_Beyond is directed by Justin Lin.',
#  'Suicide_Squad_(film) is directed by David Ayer.',
#  'X-Men:_Apocalypse is directed by Bryan Singer.',
#  'Atomic_Blonde is directed by David Leitch.',
#  'Baby_Driver is directed by Edgar Wright.',
#  'Baywatch_(film) is directed by Seth Gordon.',
#  'Blade_of_the_Immortal_(film) is directed by Takashi Miike.',
#  'Guardians_of_the_Galaxy_Vol._2 is directed by James Gunn.',
#  'The_Hitman%27s_Bodyguard is directed by Patrick Hughes.',
#  'John_Wick:_Chapter_2 is directed by Chad Stahelski.',
#  'Kingsman:_The_Golden_Circle is directed by Matthew Vaughn.',
#  'Kong:_Skull_Island is directed by Jordan Vogt-Roberts.',
#  'Logan_(film) is directed by James Mangold.',
#  'Overdrive_(film) is directed by Antonio Negret.',
#  'Power_Rangers_(film) is directed by John Gatins.',
#  'Sleepless_(2017_film) is directed by Baran bo Odar.',
#  'Spider-Man:_Homecoming is directed by Jon Watts.',
#  'Star_Wars:_The_Last_Jedi is directed by Rian Johnson.',
#  'Thor:_Ragnarok is directed by Taika Waititi.',
#  'Transformers:_The_Last_Knight is directed by Michael Bay.',
#  'Underworld:_Blood_Wars is directed by Anna Foerster.']

# %% [markdown]
# #### 3) Compute the precision and recall based on the given ground truth (column Director from tsv file) and show examples of statements that are extracted.

# %%
# compute precision and recall
fn = len(movies) - len(statements)

precision = tp / retrieved
# same as precision = tp / (tp + fp)

recall_IR = tp / relevant # relevant = len(movies)
recall_sample_sol = tp / (tp + fn) # fn = len(movies) - len(statements)


print(tp)

print ('Precision: {:.0%}'.format(precision))
print ('Recall Me: {:.0%}'.format(recall_IR))
print ('Recall: {:.0%}'.format(recall_sample_sol))
print('\n***Sample Statements***')
for s in statements[:5]:
    print (s)
# Out:
# 192
# Precision: 80%
# Recall Me: 67%
# Recall: 80%
#
# ***Sample Statements***
# 13_Assassins_(2010_film) is directed by Takashi Miike.
# 14_Blades is directed by Daniel Lee.
# 22_Bullets is directed by Richard Berry.
# Alien_vs_Ninja is directed by Seiji Chiba.
# Bad_Blood_(2010_film) is directed by Dennis Law.

# %% [markdown]
# ## Task 2: Named Entity Recognition using Hidden Markov Model
#
#
# Define a Hidden Markov Model (HMM) that recognizes Person (*PER*) entities.
# Particularly, your model must be able to recognize pairs of the form (*firstname lastname*) as *PER* entities.
# Using the given sentences as training and test set:

# %%
training_set=['The best blues singer was Bobby Bland while Ray Charles pioneered soul music .', \
              'Bobby Bland was just a singer whereas Ray Charles was a pianist , songwriter and singer .' \
              'None of them lived in Chicago .']

test_set=['Ray Charles was born in 1930 .', \
          'Bobby Bland was born the same year as Ray Charles .', \
          'Muddy Waters is the father of Chicago Blues .']

# %% [markdown]
# #### 1) Annotate your training set with the labels I (for PER entities) and O (for non PER entities).
#
#     *Hint*: Represent the sentences as sequences of bigrams, and label each bigram.
# 	Only bigrams that contain pairs of the form (*firstname lastname*) are considered as *PER* entities.

# %%
#Bigram Representation
def getBigrams(sents):
    return [b[0]+' '+b[1] for l in sents for b in zip(l.split(' ')[:-1], l.split(' ')[1:])]

bigrams = getBigrams(training_set)

#Annotation
PER = ['Bobby Bland', 'Ray Charles']
annotations = []

for b in bigrams:
    if b in PER:
        annotations.append([b, 'I'])
    else:
        annotations.append([b, 'O'])
        
print('Annotation\n', annotations,'\n')
# Out:
# Annotation
#  [['The best', 'O'], ['best blues', 'O'], ['blues singer', 'O'], ['singer was', 'O'], ['was Bobby', 'O'], ['Bobby Bland', 'I'], ['Bland while', 'O'], ['while Ray', 'O'], ['Ray Charles', 'I'], ['Charles pioneered', 'O'], ['pioneered soul', 'O'], ['soul music', 'O'], ['music .', 'O'], ['Bobby Bland', 'I'], ['Bland was', 'O'], ['was just', 'O'], ['just a', 'O'], ['a singer', 'O'], ['singer whereas', 'O'], ['whereas Ray', 'O'], ['Ray Charles', 'I'], ['Charles was', 'O'], ['was a', 'O'], ['a pianist', 'O'], ['pianist ,', 'O'], [', songwriter', 'O'], ['songwriter and', 'O'], ['and singer', 'O'], ['singer .None', 'O'], ['.None of', 'O'], ['of them', 'O'], ['them lived', 'O'], ['lived in', 'O'], ['in Chicago', 'O'], ['Chicago .', 'O']]

# %%
ats = []
for b, annotation in annotations:
    ats.append(annotation)
print(ats)

print(len(ats))

for i, a in enumerate(annotations):
    print(i)
    print(a)
# Out:
# ['O', 'O', 'O', 'O', 'O', 'I', 'O', 'O', 'I', 'O', 'O', 'O', 'O', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# 35
# 0
# ['The best', 'O']
# 1
# ['best blues', 'O']
# 2
# ['blues singer', 'O']
# 3
# ['singer was', 'O']
# 4
# ['was Bobby', 'O']
# 5
# ['Bobby Bland', 'I']
# 6
# ['Bland while', 'O']
# 7
# ['while Ray', 'O']
# 8
# ['Ray Charles', 'I']
# 9
# ['Charles pioneered', 'O']
# 10
# ['pioneered soul', 'O']
# 11
# ['soul music', 'O']
# 12
# ['music .', 'O']
# 13
# ['Bobby Bland', 'I']
# 14
# ['Bland was', 'O']
# 15
# ['was just', 'O']
# 16
# ['just a', 'O']
# 17
# ['a singer', 'O']
# 18
# ['singer whereas', 'O']
# 19
# ['whereas Ray', 'O']
# 20
# ['Ray Charles', 'I']
# 21
# ['Charles was', 'O']
# 22
# ['was a', 'O']
# 23
# ['a pianist', 'O']
# 24
# ['pianist ,', 'O']
# 25
# [', songwriter', 'O']
# 26
# ['songwriter and', 'O']
# 27
# ['and singer', 'O']
# 28
# ['singer .None', 'O']
# 29
# ['.None of', 'O']
# 30
# ['of them', 'O']
# 31
# ['them lived', 'O']
# 32
# ['lived in', 'O']
# 33
# ['in Chicago', 'O']
# 34
# ['Chicago .', 'O']

# %% [markdown]
# #### 2) Compute the transition and emission probabilities for the HMM (use smoothing parameter $\lambda$=0.5).
#
#     *Hint*: For the emission probabilities you can utilize the morphology of the words that constitute a bigram (e.g., you can count their uppercase first characters).

# %%
lambda_ = 0.5

#Transition Probabilities
transition_prob={}

I_count = 0
O_count = 0

for i, a in enumerate(annotations):
    if (i != 0):
        if a[1] == 'I':
            I_count += 1
        else:
            O_count += 1

#Prior
transition_prob['P(I|start)'] = I_count/ (I_count+O_count)
transition_prob['P(O|start)'] = 1 - transition_prob['P(I|start)']

O_after_O_count = 0
O_after_I_count = 0
I_after_O_count = 0
I_after_I_count = 0

for i, _ in enumerate(annotations):
    if (i != 0):
        if annotations[i-1][1]=='O' and annotations[i][1]=='O':
            O_after_O_count +=1
        
        elif annotations[i-1][1]=='O' and annotations[i][1]=='I':
            I_after_O_count +=1

        elif annotations[i-1][1]=='I' and annotations[i][1]=='O':
            O_after_I_count +=1

        elif annotations[i-1][1]=='I' and annotations[i][1]=='I':
            I_after_I_count +=1

transition_prob['P(O|O)'] = O_after_O_count / O_count
transition_prob['P(O|I)'] = O_after_I_count / I_count
transition_prob['P(I|O)'] = I_after_O_count / O_count
transition_prob['P(I|I)'] = I_after_I_count / I_count

print('Transition Probabilities\n',transition_prob, '\n')

#Emission Probabilities
emission_prob={}
        
default_emission = 1/len(bigrams) * (1 - lambda_)

two_upper_O_count = 0
two_upper_I_count = 0
one_upper_O_count = 0
one_upper_I_count = 0
zero_upper_O_count = 0
zero_upper_I_count = 0

for a in annotations:
    upper_count = sum(1 for c in a[0] if c.isupper())
    
    if upper_count == 2 and a[1]=='O':
        two_upper_O_count += 1
    
    elif upper_count == 1 and a[1]=='O':
        one_upper_O_count += 1

    elif upper_count == 0 and a[1]=='O':
        zero_upper_O_count += 1

    elif upper_count == 2 and a[1]=='I':
        two_upper_I_count += 1
    
    elif upper_count == 1 and a[1]=='I':
        one_upper_I_count += 1

    elif upper_count == 0 and a[1]=='I':
        zero_upper_I_count += 1
        
emission_prob['P(2_upper|O)'] = lambda_ * (two_upper_O_count / O_count) + default_emission 
emission_prob['P(2_upper|I)'] = lambda_ * (two_upper_I_count / I_count) + default_emission 
emission_prob['P(1_upper|O)'] = lambda_ * (one_upper_O_count / O_count) + default_emission 
emission_prob['P(1_upper|I)'] = lambda_ * (one_upper_I_count / I_count) + default_emission 
emission_prob['P(0_upper|O)'] = lambda_ * (zero_upper_O_count / O_count) + default_emission 
emission_prob['P(0_upper|I)'] = lambda_ * (zero_upper_I_count / I_count) + default_emission 

print('Emission Probabilities\n', emission_prob, '\n')
# Out:
# Transition Probabilities
#  {'P(I|start)': 0.11764705882352941, 'P(O|start)': 0.8823529411764706, 'P(O|O)': 0.8666666666666667, 'P(O|I)': 1.0, 'P(I|O)': 0.13333333333333333, 'P(I|I)': 0.0}
#
# Emission Probabilities
#  {'P(2_upper|O)': 0.014285714285714285, 'P(2_upper|I)': 0.5142857142857142, 'P(1_upper|O)': 0.2142857142857143, 'P(1_upper|I)': 0.014285714285714285, 'P(0_upper|O)': 0.33095238095238094, 'P(0_upper|I)': 0.014285714285714285}

# %% [markdown]
# #### 3) Predict the labels of the test set and compute the precision and the recall of your model.

# %%
#Prediction
bigrams = getBigrams(test_set)
entities=[]
prev_state='start'
for b in bigrams:
    I_prob = transition_prob['P(I|'+prev_state+')'] * emission_prob['P('+str(sum(1 for c in b if c.isupper()))+'_upper|I)']
    O_prob = transition_prob['P(O|'+prev_state+')'] * emission_prob['P('+str(sum(1 for c in b if c.isupper()))+'_upper|O)']
    
    if I_prob > O_prob:
        entities.append(b)
        prev_state = 'I'
    else:
        prev_state = 'O'

print('Predicted Entities\n', entities, '\n')
# Out:
# Predicted Entities
#  ['Ray Charles', 'Bobby Bland', 'Ray Charles', 'Muddy Waters', 'Chicago Blues']

# %%
bigrams
# Out:
# ['Ray Charles',
#  'Charles was',
#  'was born',
#  'born in',
#  'in 1930',
#  '1930 .',
#  'Bobby Bland',
#  'Bland was',
#  'was born',
#  'born the',
#  'the same',
#  'same year',
#  'year as',
#  'as Ray',
#  'Ray Charles',
#  'Charles .',
#  'Muddy Waters',
#  'Waters is',
#  'is the',
#  'the father',
#  'father of',
#  'of Chicago',
#  'Chicago Blues',
#  'Blues .']

# %% [markdown]
# Precision is **80%** while recall is **100%**.

# %% [markdown]
# #### 4) Comment on how you can further improve this model.

# %% [markdown]
# We could increase precision by computing also the probabilities for unigrams and averaging them in the prediction step.
